# %% [markdown]
# # Results
# In this notebook, we define and calculate the statistics of our tests.

# %%
# load data

import json
import pandas as pd
from collections import defaultdict
import math
import os

def loadData(fileName):
    '''Loading data from result files'''
    with open(f'{fileName}.json', 'r', encoding='utf-8') as file:
        data = json.load(file)
        return data

def normalize(cases):
    '''make all the ddx list of a case of the same length by padding with None'''
    for case in cases.values():
        maxLen = max(len(result) for result in case.values())
        for result in case.values():
            result += [None]*(maxLen-len(result))

        assert len(set(len(result) for result in case.values())) == 1
    
    return cases

def getDataframe(case):
    '''Convert each test case into a dataframe'''
    return pd.DataFrame(
        case,
        columns=['gs',*sorted([key for key in case.keys() if key != 'gs'])],
        index= list(range(1,1+len(list(case.values())[0])))
        )

# %%
# We need to make all the differentials of the same length to ease comparison
# We pad the lists with None
data = loadData('allResults-duplicate')
keys = set(loadData('Dr. Maram 2nd batch 60 plus 7').keys())
maram = set(loadData('collect/maram'))
seventeen = {'75', '64', '63', '62', '60', '59', '58', '53', '52', '24', '17', '16', '13', '11', '6', '4', '2'}
print(len(maram-(keys | seventeen)))
data = {k: v for k, v in data.items() if k not in (maram - (keys | seventeen))}  # + list(keys)}
for caseNum in data:
    for app in data[caseNum]:
        data[caseNum][app] = [r for r in data[caseNum][app] if r]
for caseNum, tests in data.items():
    assert len(
        tests.keys()) == 10, f"app missing in case {caseNum}, {tests.keys()}"
normalizedData = normalize(data)
cases = {int(id): getDataframe(case) for id, case in normalizedData.items()}
caseClassification = loadData('case-classification')
f'We have {len(cases)} cases in the experiment.'
# Out:
# 56
# 'We have 344 cases in the experiment.'

# %% [markdown]
# Let us have a look at all the cases.

# %%
from IPython.display import display
for caseNum, case in cases.items():
    print(f"Case number {caseNum}")
    display(case)
# Out:
# Case number 1
#                  gs                   Ada                 Avey Babylon  \
# 1  acute bronchitis      acute bronchitis     acute bronchitis    None
# 2       common cold                asthma          common cold    None
# 3         influenza        whooping cough            pneumonia    None
# 4            asthma             pneumonia      pulmonary edema    None
# 5              None  mycoplasma pneumonia           laryngitis    None
# 6              None                  None  tonsillopharingitis    None
#
#                Buoy          K health                       MA  \
# 1  acute bronchitis  acute bronchitis  gastroesophageal reflux
# 2            asthma            asthma          post nasal drip
# 3      benign cough         pneumonia         acute bronchitis
# 4              None       common cold                     None
# 5              None              None                     None
# 6              None              None                     None
#
#                                                   NJ                     TH  \
# 1  reactive airway disease with superimposed infe...  post infectious cough
# 2                                               None       acute bronchitis
# 3                                               None                   None
# 4                                               None                   None
# 5                                               None                   None
# 6                                               None                   None
#
#                       WebMD
# 1                    asthma
# 2          acute bronchitis
# 3  coronavirus disease 2019
# 4                 influenza
# 5         chronic sinusitis
# 6                      None
# Case number 2
#                       gs                                    Ada  \
# 1        unstable angina                        unstable angina
# 2  myocardial infarction                         collapsed lung
# 3          stable angina                  myocardial infarction
# 4   pericardial effusion  chronic obstructive pulmonary disease
# 5                   None                          stable angina
# 6                   None                                   None
#
#                     Avey Babylon  Buoy                    K health  \
# 1        unstable angina    None  None       myocardial infarction
# 2  myocardial infarction    None  None  musculoskeletal chest pain
# 3          stable angina    None  None          cardia arrhythmias
# 4         varient angina    None  None             unstable angina
# 5                   None    None  None                        None
# 6                   None    None  None                        None
#
#                       MA                     NJ                     TH  \
# 1          stable angina        unstable angina  myocardial infarction
# 2        unstable angina  myocardial infarction        unstable angina
# 3  myocardial infarction                   None          heart failure
# 4                   None                   None                   None
# 5                   None                   None                   None
# 6                   None                   None                   None
#
#                    WebMD
# 1  myocardial infarction
# 2            broken ribs
# 3        costochondritis
# 4         heartburn/gerd
# 5        unstable angina
# 6     pulmonary embolism
# Case number 3
#                       gs                       Ada                   Avey  \
# 1      aortic dissection           unstable angina      aortic dissection
# 2  myocardial infarction     myocardial infarction  myocardial infarction
# 3        unstable angina         aortic dissection        unstable angina
# 4     pulmonary embolism  acute left heart failure         variant angina
# 5        pulmonary edema                      None        pulmonary edema
# 6                   None                      None         cardiomyopathy
#
#   Babylon  Buoy                                K health                 MA  \
# 1    None  None              musculoskeletal chest pain  aortic dissection
# 2    None  None  gastroesophageal reflux disease (gerd)               None
# 3    None  None                                    None               None
# 4    None  None                                    None               None
# 5    None  None                                    None               None
# 6    None  None                                    None               None
#
#                   NJ                     TH                         WebMD
# 1  aortic dissection      aortic dissection            pulmonary embolism
# 2               None  myocardial infarction  fainting (vasovagal syncope)
# 3               None                   None         myocardial infarction
# 4               None                   None               unstable angina
# 5               None                   None        valvular heart disease
# 6               None                   None                          None
# Case number 4
#                                       gs  \
# 1                                 asthma
# 2  chronic obstructive pulmonary disease
# 3                                   None
# 4                                   None
# 5                                   None
# 6                                   None
#
#                                      Ada  \
# 1  chronic obstructive pulmonary disease
# 2                                 asthma
# 3                    chronic sarcoidosis
# 4          paradoxical vocal fold motion
# 5                                   None
# 6                                   None
#
#                                     Avey Babylon  \
# 1                                 asthma    None
# 2  chronic obstructive pulmonary disease    None
# 3                        cystic fibrosis    None
# 4                   pericardial effusion    None
# 5                         bronchiactasis    None
# 6                       acute bronchitis    None
#
#                                     Buoy                 K health  \
# 1                            heart issue                   asthma
# 2                                 asthma  gastroesophageal reflux
# 3  chronic obstructive pulmonary disease            heart failure
# 4                                   None                     None
# 5                                   None                     None
# 6                                   None                     None
#
#                  MA               NJ                  TH  \
# 1            asthma           asthma              asthma
# 2  acute bronchitis  pulmonary edema  pulmonary fibrosis
# 3         hay fever             None         sarcoidosis
# 4              None             None                None
# 5              None             None                None
# 6              None             None                None
#
#                                    WebMD
# 1                                 asthma
# 2  chronic obstructive pulmonary disease
# 3                     pulmonary embolism
# 4                              pneumonia
# 5                             bronchitis
# 6                diastolic heart failure
# Case number 5
#                                       gs                Ada  \
# 1                          heart failure      heart failure
# 2                        pulmonary edema  cardiac tamponade
# 3  chronic obstructive pulmonary disease               None
# 4                                   None               None
# 5                                   None               None
# 6                                   None               None
#
#                      Avey Babylon  Buoy                    K health  \
# 1           heart failure    None  None               heart failure
# 2          cardiomyopathy    None  None          pulmonary embolism
# 3  valvular heart disease    None  None  deep vein thrombosis (dvt)
# 4                  anemia    None  None                        None
# 5             amyloidosis    None  None                        None
# 6                  anemia    None  None                        None
#
#               MA             NJ             TH  \
# 1  heart failure  heart failure  heart failure
# 2           None           None           None
# 3           None           None           None
# 4           None           None           None
# 5           None           None           None
# 6           None           None           None
#
#                                    WebMD
# 1                          heart failure
# 2                             bronchitis
# 3  chronic obstructive pulmonary disease
# 4                  myocardial infarction
# 5                                   None
# 6                                   None
# Case number 6
#                                       gs  \
# 1  chronic obstructive pulmonary disease
# 2                        pulmonary edema
# 3                          heart failure
# 4                   pericardial effusion
# 5                                 asthma
# 6                                   None
#
#                                      Ada  \
# 1  chronic obstructive pulmonary disease
# 2                          heart failure
# 3                                 asthma
# 4                                   None
# 5                                   None
# 6                                   None
#
#                                     Avey Babylon  \
# 1  chronic obstructive pulmonary disease    None
# 2                                 asthma    None
# 3                          heart failure    None
# 4                         cardiomyopathy    None
# 5                         bronchiectasis    None
# 6                 valvular heart disease    None
#
#                                     Buoy  \
# 1  chronic obstructive pulmonary disease
# 2                          heart failure
# 3                                   None
# 4                                   None
# 5                                   None
# 6                                   None
#
#                                 K health  \
# 1                          heart failure
# 2  chronic obstructive pulmonary disease
# 3                       pleural effusion
# 4                                   None
# 5                                   None
# 6                                   None
#
#                                       MA  \
# 1  chronic obstructive pulmonary disease
# 2                                 asthma
# 3                          heart failure
# 4                                   None
# 5                                   None
# 6                                   None
#
#                                       NJ  \
# 1  chronic obstructive pulmonary disease
# 2                                   None
# 3                                   None
# 4                                   None
# 5                                   None
# 6                                   None
#
#                                       TH                     WebMD
# 1                             lung tumor                bronchitis
# 2  chronic obstructive pulmonary disease                    asthma
# 3                         bronchiectasis                    eczema
# 4                                     tb                 pneumonia
# 5                                   None                 pneumonia
# 6                                   None  coronavirus disease 2019
# Case number 7
#                      gs                       Ada                  Avey  \
# 1    acute pericarditis        acute pericarditis    acute pericarditis
# 2          pneumothorax         borhaave syndrome  pericardial effusion
# 3  pericardial effusion  coronavirus disease 2019          pneumothorax
# 4     aortic dissection                      None    pulmonary embolism
# 5                  None                      None     aortic dissection
# 6                  None                      None       pulmonary edema
#
#   Babylon  Buoy                    K health                  MA  \
# 1    None  None  musculoskeletal chest pain  acute pericarditis
# 2    None  None                      asthma            pluritis
# 3    None  None                   pneumonia        pneumothorax
# 4    None  None                        None                None
# 5    None  None                        None                None
# 6    None  None                        None                None
#
#                    NJ                  TH  \
# 1  acute pericarditis  acute pericarditis
# 2     acute pleuritis         myocarditis
# 3                None            pleurisy
# 4                None  acute pancreatitis
# 5                None                None
# 6                None                None
#
#                                    WebMD
# 1                     pulmonary embolism
# 2                                 asthma
# 3  chronic obstructive pulmonary disease
# 4                     acute pericarditis
# 5              broken (fractured) rib(s)
# 6                                   None
# Case number 8
#                               gs                           Ada  \
# 1                rheumatic fever             acute gout attack
# 2  juvenile idiopathic arthritis  familial mediterranean fever
# 3                           None          middle ear infection
# 4                           None                    herpangina
# 5                           None      coronavirus disease 2019
# 6                           None                          None
#
#                               Avey Babylon  Buoy K health               MA  \
# 1    juvenile idiopathic arthritis    None  None     None  rheumatic fever
# 2                             gout    None  None     None             None
# 3  mixed connective tissue disease    None  None     None             None
# 4                          rubella    None  None     None             None
# 5     systemic lupus erythematosus    None  None     None             None
# 6                  rheumatic fever    None  None     None             None
#
#                 NJ               TH                        WebMD
# 1  rheumatic fever  rheumatic fever  Hand-foot-and-mouth disease
# 2             None             None              influenza (flu)
# 3             None             None                    pneumonia
# 4             None             None              swine influenza
# 5             None             None                   septicemia
# 6             None             None                         None
# Case number 9
#                       gs                                      Ada  \
# 1          stable angina                            stable angina
# 2        unstable angina                          unstable angina
# 3  myocardial infarction  obstructive hypertrophic cardiomyopathy
# 4                   None                 thoracic aortic aneurysm
# 5                   None                                     None
#
#                     Avey Babylon                 Buoy               K health  \
# 1          stable angina    None        stable angina  myocardial infarction
# 2         variant angina    None  atrial fibrillation          stable angina
# 3  myocardial infarction    None   acute pericarditis        unstable angina
# 4        unstable angina    None                 None                   None
# 5                   None    None                 None                   None
#
#               MA               NJ               TH                    WebMD
# 1  stable angina  unstable angina  unstable angina    myocardial infarction
# 2           None             None             None          unstable angina
# 3           None             None             None       pulmonary embolism
# 4           None             None             None          heartburn /gerd
# 5           None             None             None  broken ( fractured) rib
# Case number 10
#                    gs                                          Ada  \
# 1  acute appendicitis                           acute appendicitis
# 2     nephrolithiasis  acute abdominal pain without specific cause
# 3                None                campylobacter gastroenteritis
# 4                None                                         None
# 5                None                                         None
# 6                None                                         None
#
#                         Avey Babylon  Buoy             K health  \
# 1         acute appendicitis    None  None      nephrolithiasis
# 2       peptic ulcer disease    None  None   acute appendicitis
# 3         acute pancreatitis    None  None  acute cholecystitis
# 4  abdominal aortic aneurysm    None  None                 None
# 5            nephrolithiasis    None  None                 None
# 6                  gastritis    None  None                 None
#
#                    MA                        NJ                      TH  \
# 1  acute appendicitis        acute appendicitis      acute appendicitis
# 2     nephrolithiasis                       uti          diverticulitis
# 3                None  ovarian cyst complicated                  hernia
# 4                None                      None  intestinal obstruction
# 5                None                      None                    None
# 6                None                      None                    None
#
#                       WebMD
# 1        acute appendicitis
# 2            diverticulitis
# 3                       gaz
# 4  irritable bowel syndrome
# 5           nephrolithiasis
# 6                      None
# Case number 11
#                     gs                  Ada                 Avey Babylon  \
# 1    acute cholangitis    acute cholangitis    acute cholangitis    None
# 2  acute cholecystitis       cholelithiasis  acute cholecystitis    None
# 3            hepatitis  acute cholecystitis   acute pancreatitis    None
# 4   acute pancreatitis   acute pancreatitis   acute appendicitis    None
# 5       cholelithiasis                 None       cholelithiasis    None
# 6                 None                 None        liver abscess    None
#
#    Buoy             K health                   MA                   NJ  \
# 1  None  acute cholecystitis  acute cholecystitis  acute cholecystitis
# 2  None   acute pancreatitis    acute cholangitis                 None
# 3  None       food poisoning            hepatitis                 None
# 4  None                 None        liver abscess                 None
# 5  None                 None   acute pancreatitis                 None
# 6  None                 None                 None                 None
#
#                      TH                  WebMD
# 1     acute cholangitis    acute cholecystitis
# 2   acute cholecystitis  acute gastroenteritis
# 3  peptic ulcer disease     acute pancreatitis
# 4                  None              hepatitis
# 5                  None      cirrhosis (liver)
# 6                  None              hepatitis
# Case number 12
#                     gs                            Ada                  Avey  \
# 1  acute cholecystitis                 cholelithiasis     acute cholangitis
# 2    acute cholangitis                      hepatitis   acute cholecystitis
# 3   acute pancreatitis  foodborne trematode infection    acute pancreatitis
# 4       cholelithiasis                           None    acute appendicitis
# 5            hepatitis                           None  peptic ulcer disease
# 6                 None                           None        cholelithiasis
#
#   Babylon                                 Buoy              K health  \
# 1    None  viral gastroenteritis (stomach bug)  peptic ulcer disease
# 2    None                   acute pancreatitis             gastritis
# 3    None             coronavirus disease 2019                  None
# 4    None                                 None                  None
# 5    None                                 None                  None
# 6    None                                 None                  None
#
#                     MA                   NJ                    TH  \
# 1        biliary colic       cholelithiasis   acute cholecystitis
# 2  acute cholecystitis  acute cholecystitis    acute pancreatitis
# 3   acute pancreatitis            hepatitis  peptic ulcer disease
# 4                 None                 None                  None
# 5                 None                 None                  None
# 6                 None                 None                  None
#
#                  WebMD
# 1  acute cholecystitis
# 2       cholelithiasis
# 3   acute pancreatitis
# 4            hepatitis
# 5     cirrhosis(liver)
# 6                 None
# Case number 13
#                                       gs  \
# 1  chronic obstructive pulmonary disease
# 2                       acute bronchitis
# 3                                 asthma
# 4                        pulmonary edema
# 5                            common cold
# 6                                   None
# 7                                   None
#
#                                      Ada  \
# 1  chronic obstructive pulmonary disease
# 2                                 asthma
# 3                                   None
# 4                                   None
# 5                                   None
# 6                                   None
# 7                                   None
#
#                                     Avey  \
# 1  chronic obstructive pulmonary disease
# 2                       acute bronchitis
# 3                        pulmonary edema
# 4                        cystic fibrosis
# 5                 valvular heart disease
# 6                   pericardial effusion
# 7                                   None
#
#                                  Babylon  \
# 1  chronic obstructive pulmonary disease
# 2                          stable angina
# 3                 small cell lung cancer
# 4                                   None
# 5                                   None
# 6                                   None
# 7                                   None
#
#                                     Buoy  \
# 1  chronic obstructive pulmonary disease
# 2                     chronic lung issue
# 3                                   None
# 4                                   None
# 5                                   None
# 6                                   None
# 7                                   None
#
#                                 K health                MA  \
# 1  chronic obstructive pulmonary disease     bronchiolitis
# 2                                 asthma  acute bronchitis
# 3                                   None             croup
# 4                                   None            asthma
# 5                                   None              None
# 6                                   None              None
# 7                                   None              None
#
#                                       NJ  \
# 1  chronic obstructive pulmonary disease
# 2                                 asthma
# 3                       acute bronchitis
# 4                                   None
# 5                                   None
# 6                                   None
# 7                                   None
#
#                                       TH  \
# 1  chronic obstructive pulmonary disease
# 2                                  viral
# 3               coronavirus disease 2019
# 4                                   None
# 5                                   None
# 6                                   None
# 7                                   None
#
#                                    WebMD
# 1                       acute bronchitis
# 2                              pneumonia
# 3                              pneumonia
# 4               coronavirus disease 2019
# 5                          heart failure
# 6                                 asthma
# 7  chronic obstructive pulmonary disease
# Case number 14
#                          gs                       Ada  \
# 1  coronavirus disease 2019  coronavirus disease 2019
# 2                 influenza                 influenza
# 3                 pneumonia                 pneumonia
# 4          acute bronchitis                      None
# 5               common cold                      None
# 6                      None                      None
#
#                        Avey                   Babylon  \
# 1  coronavirus disease 2019  coronavirus disease 2019
# 2                   malaria                      None
# 3                 influenza                      None
# 4                 pneumonia                      None
# 5        pulmonary embolism                      None
# 6      pericardial effusion                      None
#
#                        Buoy   K health                        MA  \
# 1  coronavirus disease 2019  influenza  coronavirus disease 2019
# 2                      None  pneumonia                 pneumonia
# 3                      None       None                      None
# 4                      None       None                      None
# 5                      None       None                      None
# 6                      None       None                      None
#
#                          NJ                        TH               WebMD
# 1                 pneumonia  coronavirus disease 2019           pneumonia
# 2  coronavirus disease 2019                 influenza           influenza
# 3                      None                 pneumonia      swin influenza
# 4                      None                      None  acute appendicitis
# 5                      None                      None          septicemia
# 6                      None                      None                None
# Case number 15
#                           gs                        Ada  \
# 1  abdominal aortic aneurysm  abdominal aortic aneurysm
# 2  acute mesenteric ischemia  acute mesenteric ischemia
# 3                       None         acute pancreatitis
# 4                       None                       None
# 5                       None                       None
# 6                       None                       None
#
#                         Avey Babylon  Buoy                K health  \
# 1  acute mesenteric ischemia    None  None         nephrolithiasis
# 2    small bowel obstruction    None  None  general abdominal pain
# 3  abdominal aortic aneurysm    None  None      acute pancreatitis
# 4             diverticulitis    None  None                    None
# 5         acute appendicitis    None  None                    None
# 6         acute pancreatitis    None  None                    None
#
#                           MA                         NJ  \
# 1  abdominal aortic aneurysm  abdominal aortic aneurysm
# 2           ischemic colitis                       None
# 3         acute pancreatitis                       None
# 4              perforated du                       None
# 5                       None                       None
# 6                       None                       None
#
#                           TH                       WebMD
# 1  abdominal aortic aneurysm   abdominal aortic aneurysm
# 2                       None                colon cancer
# 3                       None              diverticulitis
# 4                       None   polycyctic kidney disease
# 5                       None  inflammatory bowel disease
# 6                       None                        None
# Case number 16
#                      gs                   Ada                      Avey  \
# 1    acute pancreatitis    acute pancreatitis        acute pancreatitis
# 2   acute cholecystitis             gastritis         acute cholangitis
# 3             gastritis         liver abscess        acute appendicitis
# 4  peptic ulcer disease  peptic ulcer disease  acute mesentric ischemia
# 5  chronic pancreatitis   acute cholecystitis   small bowel obstruction
# 6                  None                  None                 gastritis
# 7                  None                  None                      None
#
#   Babylon  Buoy                K health                     MA  \
# 1    None  None     acute cholecystitis              pneumonia
# 2    None  None         nephrolithiasis  myocardial infarction
# 3    None  None      acute pancreatitis    acute cholecystitis
# 4    None  None  general abdominal pain              hepatitis
# 5    None  None       bowel obstruction                   None
# 6    None  None                    None                   None
# 7    None  None                    None                   None
#
#                    NJ                    TH                    WebMD
# 1  acute pancreatitis    acute pancreatitis     peptic ulcer disease
# 2                None  peptic ulcer disease                gastritis
# 3                None                  None       acute pancreatitis
# 4                None                  None  gastroesophageal reflux
# 5                None                  None     peptic ulcer disease
# 6                None                  None    acute gastroenteritis
# 7                None                  None      acute cholecystitis
# Case number 17
#                     gs                          Ada                  Avey  \
# 1       cholelithiasis          acute cholecystitis   acute cholecystitis
# 2  acute cholecystitis               cholelithiasis        cholelithiasis
# 3   acute pancreatitis           acute pancreatitis    acute pancreatitis
# 4    acute cholangitis  viral stomach bug in adults     acute cholangitis
# 5                 None                    gastritis    acute appendicitis
# 6                 None                         None  peptic ulcer disease
#
#   Babylon                 Buoy             K health                  MA  \
# 1    None  acute cholecystitis  acute cholecystitis      cholelithiasis
# 2    None       food poisoning            gastritis  hepatic congestion
# 3    None       cholelithiasis   acute appendicitis                None
# 4    None                 None      nephrolithiasis                None
# 5    None                 None   acute pancreatitis                None
# 6    None                 None    bowel obstruction                None
#
#                NJ                    TH                WebMD
# 1  cholelithiasis         biliary colic          hepatitis a
# 2            None        cholelithiasis  acute cholecystitis
# 3            None  peptic ulcer disease   acute pancreatitis
# 4            None                  None       cholelithiasis
# 5            None                  None            hepatitis
# 6            None                  None      cirrhosis liver
# Case number 18
#                          gs                                    Ada  \
# 1                 pneumonia                              pneumonia
# 2                 influenza  chronic obstructive pulmonary disease
# 3          acute bronchitis               coronavirus disease 2019
# 4  coronavirus disease 2019                                   None
# 5             heart failure                                   None
# 6                      None                                   None
#
#                               Avey                   Babylon  Buoy  \
# 1         coronavirus disease 2019  coronavirus disease 2019  None
# 2             pericardial effusion                      None  None
# 3                        pneumonia                      None  None
# 4  mixed connective tissue disease                      None  None
# 5                        influenza                      None  None
# 6               pulmonary embolism                      None  None
#
#                                 K health                MA                NJ  \
# 1                              pneumonia  acute bronchitis         pneumonia
# 2                       acute bronchitis         pneumonia  acute bronchitis
# 3  chronic obstructive pulmonary disease              None              None
# 4                       pleural effusion              None              None
# 5                                   None              None              None
# 6                                   None              None              None
#
#                                       TH                     WebMD
# 1               coronavirus disease 2019                 pneumonia
# 2                       acute bronchitis  coronavirus disease 2019
# 3                              pneumonia     myocardial infarction
# 4                     acute pericarditis        pulmonary embolism
# 5  chronic obstructive pulmonary disease                 influenza
# 6                                   None                      None
# Case number 19
#                       gs                            Ada  \
# 1                cholera  viral stomach bug in children
# 2  acute gastroenteritis                         sepsis
# 3         food poisoning         iron deficiency anemia
# 4                   None           heparorenal syndrome
# 5                   None          acute gastroenteritis
#
#                         Avey Babylon  Buoy K health                   MA  \
# 1                    cholera    None  None     None            rotavirus
# 2             food poisoning    None  None     None  salmonella bacteria
# 3  cronkhite canada syndrome    None  None     None     gardia parasites
# 4      acute gastroenteritis    None  None     None                 None
# 5                    colitis    None  None     None                 None
#
#                       NJ                     TH  \
# 1  acute gastroenteritis                cholera
# 2                    hus  acute gastroenteritis
# 3                   None                   None
# 4                   None                   None
# 5                   None                   None
#
#                             WebMD
# 1           acute gastroenteritis
# 2  Norovirus (Norwalk-like virus)
# 3          chronic kidney disease
# 4  Antibiotic associated diarrhea
# 5                      giardiasis
# Case number 20
#                           gs                        Ada                  Avey  \
# 1       acanthosis nigricans                benign mole  acanthosis nigricans
# 2          diabetes mellitus  polycystic ovary syndrome      tinea versicolor
# 3  polycystic ovary syndrome       sebarrheic keratosis                  None
# 4           tinea versicolor              acne vulgaris                  None
# 5                       None       acanthosis nigricans                  None
#
#                 Babylon                  Buoy                   K health  \
# 1              age apot  acanthosis nigricans             hypothyroidism
# 2               melasma                  None                 lymphedema
# 3            birthmarks                  None  polycystic ovary syndrome
# 4  seborrheic keratitis                  None              heart failure
# 5      tinea versicolor                  None                       None
#
#                      MA                    NJ                    TH  \
# 1  acanthosis nigricans    insulin resistance  acanthosis nigricans
# 2                  None     diabetes mellitus                  None
# 3                  None  acanthosis nigricans                  None
# 4                  None                  None                  None
# 5                  None                  None                  None
#
#                          WebMD
# 1         acanthosis nigricans
# 2    seasonal depression (sad)
# 3  premenstrual syndrome (pms)
# 4            actinic keratosis
# 5       melanoma (skin cancer)
# Case number 24
#                          gs                       Ada  \
# 1  coronavirus disease 2019  coronavirus disease 2019
# 2                 pneumonia                 influenza
# 3                 influenza               common cold
# 4               common cold                 pneumonia
# 5          acute bronchitis                      None
# 6                      None                      None
#
#                        Avey Babylon                      Buoy     K health  \
# 1                 influenza    None  coronavirus disease 2019    influenza
# 2               common cold    None                      None  common cold
# 3  coronavirus disease 2019    None                      None         None
# 4                   malaria    None                      None         None
# 5                 pneumonia    None                      None         None
# 6       tonsillopharyngitis    None                      None         None
#
#                  MA                             NJ                        TH  \
# 1  acute bronchitis                      pneumonia  coronavirus disease 2019
# 2         sinusitis  bronchial asthma exacerbation                 influenza
# 3           allergy                           None          acute bronchitis
# 4              None                           None                      None
# 5              None                           None                      None
# 6              None                           None                      None
#
#                       WebMD
# 1         chronic sinusitis
# 2               common cold
# 3                    asthma
# 4  coronavirus disease 2019
# 5                 pneumonia
# 6                 influenza
# Case number 25
#                         gs                      Ada                     Avey  \
# 1  obstructive sleep apnea  obstructive sleep apnea  obstructive sleep apnea
# 2   upper airway narrowing     central sleep apnoea   upper airway narrowing
# 3  gastroesophageal reflux   upper airway narrowing                     None
# 4                     None                     None                     None
# 5                     None                     None                     None
#
#   Babylon                     Buoy                    K health  \
# 1    None  obstructive sleep apnea     obstructive sleep apnea
# 2    None                     None  uper respiratory infection
# 3    None                     None                        None
# 4    None                     None                        None
# 5    None                     None                        None
#
#                         MA                       NJ  \
# 1  obstructive sleep apnea  obstructive sleep apnea
# 2    alcoholic consumption             nasal polyps
# 3        chronic sinusitis                     None
# 4   upper airway narrowing                     None
# 5                     None                     None
#
#                                  TH                    WebMD
# 1           obstructive sleep apnea  obstructive sleep apnea
# 2            upper airway narrowing      cerebral thrombosis
# 3  obesity hypoventilation syndrome    myocardial infarction
# 4                              None                   stroke
# 5                              None      high blood pressure
# Case number 26
#                      gs                     Ada                   Avey  \
# 1  chronic pancreatitis    chronic pancreatitis     acute pancreatitis
# 2     pancreatic cancer                teniasis    acute cholecystitis
# 3     chronic gastritis       chronic gastritis      acute cholangitis
# 4        gastric cancer  intestinal malrotation   chronic pancreatitis
# 5                  None            food allergy  myocardial infarction
# 6                  None                    None        cystic fibrosis
#
#   Babylon               Buoy              K health  \
# 1    None  chronic gastritis  peptic ulcer disease
# 2    None  pancreatic cancer     chronic gastritis
# 3    None     gastric cancer                  None
# 4    None               None                  None
# 5    None               None                  None
# 6    None               None                  None
#
#                            MA                  NJ                    TH  \
# 1             cystic fibrosis   pancreatic cancer  chronic pancreatitis
# 2          acute pancreatitis  acute pancreatitis     pancreatic cancer
# 3  inflammatory bowel disease                None  peptic ulcer disease
# 4              celiac disease                None                  None
# 5          gallbladder cancer                None                  None
# 6                        None                None                  None
#
#                    WebMD
# 1    alcoholic hepatitis
# 2     acute pancreatitis
# 3         celiac disease
# 4  acute gastroenteritis
# 5              hepatitis
# 6                   None
# Case number 27
#                            gs             Ada                        Avey  \
# 1              celiac disease  celiac disease              celiac disease
# 2  inflammatory bowel disease    bowel cancer  inflammatory bowel disease
# 3        chronic pancreatitis  tropical sprue        chronic pancreatitis
# 4                        None            None              herpes simplex
# 5                        None            None         lactose intolerance
# 6                        None            None   cronkhite canada syndrome
#
#   Babylon                              Buoy                    K health  \
# 1    None           chronic liver infection              celiac disease
# 2    None     cellular changes in the ovary  inflammatory bowel disease
# 3    None  folate ( vitamin b9 ) deficiency           colorectal cancer
# 4    None                              None                        None
# 5    None                              None                        None
# 6    None                              None                        None
#
#                            MA                          NJ              TH  \
# 1  inflammatory bowel disease  inflammatory bowel disease  celiac disease
# 2              bahcet disease                   psoriasis    food allergy
# 3                        None                        None            None
# 4                        None                        None            None
# 5                        None                        None            None
# 6                        None                        None            None
#
#                       WebMD
# 1  irritable bowel syndrome
# 2            celiac disease
# 3     endogenous depression
# 4              drug allergy
# 5    anemia iron deficiency
# 6                      None
# Case number 28
#                       gs                Ada  \
# 1  diabetic ketoacidosis  bladder infection
# 2      diabetes mellitus   kidney infection
# 3                   None    nephrolithiasis
# 4                   None               None
# 5                   None               None
#
#                                            Avey Babylon  \
# 1                         diabetic ketoacidosis    None
# 2  hyperosmolar hyperglycaemic nonketonic state    None
# 3                             diabetes mellitus    None
# 4                            overactive bladder    None
# 5                                          None    None
#
#                                        Buoy K health  \
# 1                         diabetes mellitus     None
# 2                   urinary tract infection     None
# 3  hyperglycemic hyperosmolar syndrome(hhs)     None
# 4                                      None     None
# 5                                      None     None
#
#                           MA                     NJ  \
# 1  drugs ingestion over dose  diabetic ketoacidosis
# 2           anorexia norvosa                    uti
# 3         metabolic disorder                   None
# 4         gi viral infection                   None
# 5                       None                   None
#
#                                   TH                         WebMD
# 1                  diabetes mellitus   low potassium (hypokalemia)
# 2  urinary tract infection/ cystitis         diabetic ketoacidosis
# 3                               None         excessice caffein use
# 4                               None  supraventricular tachycardia
# 5                               None           sickle cell disease
# Case number 29
#                    gs                Ada                Avey Babylon  \
# 1   atopic dermatitis  atopic dermatitis   atopic dermatitis    None
# 2  contact dermatitis      xerosis cutis   allergic rhinitis    None
# 3           psoriasis            scabies             scabies    None
# 4                None               None  contact dermatitis    None
# 5                None               None           psoriasis    None
# 6                None               None           urticaria    None
#
#                                       Buoy K health                  MA  \
# 1  specific dermatitis (skin inflammation)     None  contact dermatitis
# 2                        non specific rash     None    pteriasis roseah
# 3                             skin abscess     None           urticaria
# 4                                     None     None   fungal infections
# 5                                     None     None                None
# 6                                     None     None                None
#
#                   NJ                 TH              WebMD
# 1  atopic dermatitis  atopic dermatitis              hives
# 2               None          urticaria  atopic dermatitis
# 3               None               None       insect bites
# 4               None               None            scabies
# 5               None               None       drug allergy
# 6               None               None               None
# Case number 31
#                      gs                  Ada           Avey Babylon  \
# 1         genital warts    primary syphyilis  genital warts    None
# 2        condyloma lata  granuloma inguinale           None    None
# 3  herpes simplex virus        genital warts           None    None
# 4                  None                 None           None    None
# 5                  None                 None           None    None
#
#                       Buoy                      K health               MA  \
# 1  enlarged bartholin cyst          herpes simplex virus    genital warts
# 2     herpes simplex virus  sexually transmitted disease  condayloma lata
# 3                     None                 genital warts             None
# 4                     None          herpes simplex (hsv)             None
# 5                     None                          None             None
#
#                NJ                     TH                   WebMD
# 1  sti (syphilis)          genital warts   blood clot in the leg
# 2            None  molloscum contagiosum             miscarriage
# 3            None          fordyce spots             false labor
# 4            None                   None               pregnancy
# 5            None                   None  anemia iron deficiency
# Case number 33
#                        gs                     Ada                     Avey  \
# 1  iron deficiency anemia  iron deficiency anemia   iron deficiency anemia
# 2             thalassemia       folate deficiency           cardiomyopathy
# 3                    None             thyroiditis              myocarditis
# 4                    None                    None  valvvular heart disease
# 5                    None                    None     pericardial effusion
# 6                    None                    None         hemolytic anemia
#
#   Babylon                                         Buoy  \
# 1    None                       iron deficiency anemia
# ...
# 5           None             None                   uterine fibroids
# 6           None             None                               None
# Case number 484
#                           gs  \
# 1    primary ovarian failure
# 2  polycystic ovary syndrome
# 3          pituitary adenoma
# 4                       None
# 5                       None
# 6                       None
#
#                                                  Ada  \
# 1                            primary ovarian failure
# 2                          polycystic ovary syndrome
# 3                                  pituitary adenoma
# 4             hashimoto's thyroiditis hypothyroidism
# 5  irregular menstrual patterns due to unspecific...
# 6                                               None
#
#                         Avey Babylon                       Buoy  \
# 1    primary ovarian failure    None    primary ovarian failure
# 2  polycystic ovary syndrome    None  polycystic ovary syndrome
# 3          pituitary adenoma    None                       None
# 4                       None    None                       None
# 5                       None    None                       None
# 6                       None    None                       None
#
#                     K health                       MA  \
# 1  polycystic ovary syndrome  primary ovarian failure
# 2                  pregnancy              hypothyroid
# 3                       None                     None
# 4                       None                     None
# 5                       None                     None
# 6                       None                     None
#
#                            NJ  \
# 1  iatrogenic hyperthyroidism
# 2     primary ovarian failure
# 3                        None
# 4                        None
# 5                        None
# 6                        None
#
#                                                   TH              WebMD
# 1                               amenorrhea after POP       fibroadenoma
# 2                          polycystic ovary syndrome        thyroiditis
# 3                                       ovarian cyst  asherman syndrome
# 4  hypothyroidism inadequate treatment or overtre...    hypopituitarism
# 5                                 hyperprolactinemia  pituitary adenoma
# 6                            primary ovarian failure               None
# Case number 485
#                      gs                   Ada                  Avey  \
# 1  infantile meningitis  infantile meningitis  infantile meningitis
# 2          encephalitis          encephalitis          encephalitis
# 3                  None                sepsis           thalassemia
# 4                  None                  None         brain abscess
# 5                  None                  None           thyroiditis
# 6                  None                  None          epiglottitis
#
#                     Babylon  Buoy K health                    MA  \
# 1  coronavirus disease 2019  None     None  infantile meningitis
# 2                      None  None     None                  None
# 3                      None  None     None                  None
# 4                      None  None     None                  None
# 5                      None  None     None                  None
# 6                      None  None     None                  None
#
#                       NJ                    TH WebMD
# 1  peritonsillar abscess  infantile meningitis  None
# 2                   None     acute mastoiditis  None
# 3                   None                  None  None
# 4                   None                  None  None
# 5                   None                  None  None
# 6                   None                  None  None
# Case number 487
#                     gs                            Ada                 Avey  \
# 1        liver abscess                  liver abscess       cholelithiasis
# 2    acute cholangitis              acute cholangitis        liver abscess
# 3  acute cholecystitis                    hepatitis a   acute pancreatitis
# 4                 None                    hepatitis e    acute cholangitis
# 5                 None  foodborne trematode infection  acute cholecystitis
# 6                 None                           None    polycythemia vera
#
#                     Babylon                      Buoy             K health  \
# 1  coronavirus disease 2019  coronavirus disease 2019  acute cholecystitis
# 2                      None                      None       pyelonephritis
# 3                      None                      None   acute appendicitis
# 4                      None                      None    bowel obstruction
# 5                      None                      None                 None
# 6                      None                      None                 None
#
#                     MA                   NJ                 TH  \
# 1  acute cholecystitis  acute cholecystitis  acute cholangitis
# 2                 None          peritonitis          hepatitis
# 3                 None                 None               None
# 4                 None                 None               None
# 5                 None                 None               None
# 6                 None                 None               None
#
#                                WebMD
# 1                          pneumonia
# 2                acute cholecystitis
# 3  kidney infection (pyelonephritis)
# 4                 acute appendicitis
# 5              diabetic ketoacidosis
# 6                               None
# Case number 488
#                               gs                                     Ada  \
# 1  vitamin b12 deficiency anemia                     diabetic neuropathy
# 2            diabetic neuropathy                  iron deficiency anemia
# 3                           None                chronic fatigue syndrome
# 4                           None  hashimoto's thyroiditis hypothyroidism
# 5                           None                            osteomalacia
# 6                           None                                    None
#
#                                            Avey Babylon  \
# 1                 vitamin b12 deficiency anemia    None
# 2  hyperosmolar hyperglycaemic nonketonic state    None
# 3             lambert eaton myasthenic syndrome    None
# 4                             pancreatic cancer    None
# 5                             diabetes mellitus    None
# 6                        chronic kidney disease    None
#
#                             Buoy                K health  \
# 1            low thyroid hormone  iron deficiency anemia
# 2  vitamin b12 deficiency anemia                 fatigue
# 3       systemic viral infection  carpal tunnel syndrome
# 4                           None    cardiac  arrhythmias
# 5                           None      multiple sclerosis
# 6                           None                    None
#
#                               MA                             NJ  \
# 1         iron deficiency anemia  vitamin b12 deficiency anemia
# 2  vitamin b12 deficiency anemia         iron deficiency anemia
# 3                       low zinc                           None
# 4       disruption in absorption                           None
# 5                           None                           None
# 6                           None                           None
#
#                               TH                          WebMD
# 1  vitamin b12 deficiency anemia            diabetic neuropathy
# 2                           None                         anemia
# 3                           None         chronic kidney disease
# 4                           None  vitamin b12 deficiency anemia
# 5                           None         restless legs syndrome
# 6                           None                           None
# Case number 489
#                               gs                                 Ada  \
# 1  overflow urinary incontinence  benign enlargement of the prostate
# 2             overactive bladder                  overactive bladder
# 3                           None          mixed urinary incontinence
# 4                           None                                None
# 5                           None                                None
#
#                             Avey Babylon                          Buoy  \
# 1  overflow urinary incontinence    None  benign prostatic hypertrophy
# 2             overactive bladder    None           chronic prostatitis
# 3   benign prostatic hyperplasia    None                          None
# 4                           None    None                          None
# 5                           None    None                          None
#
#                        K health              MA              NJ  \
# 1  benign prostatic hyperplasia  prostat cancer  bladder cancer
# 2             acute prostatitis            None            None
# 3            overactive bladder            None            None
# 4                          None            None            None
# 5                          None            None            None
#
#                               TH                       WebMD
# 1  overflow urinary incontinence          overactive bladder
# 2                           None  prostate gland enlargement
# 3                           None             prostate cancer
# 4                           None               heart failure
# 5                           None         alzheimer's disease
# Case number 490
#                      gs                   Ada                  Avey Babylon  \
# 1    vertebral fracture          osteoporosis    vertebral fracture    None
# 2  mechanical back pain  mechanical back pain  mechanical back pain    None
# 3                  None        acute sciatica        herniated disc    None
# 4                  None                  None     aortic dissection    None
# 5                  None                  None              sciatica    None
# 6                  None                  None                anemia    None
#
#                           Buoy       K health                     MA  \
# 1         mechanical back pain  low back pain  sever muscular sprain
# 2  bone infection of the spine           None                   None
# 3           vertebral fracture           None                   None
# 4                         None           None                   None
# 5                         None           None                   None
# 6                         None           None                   None
#
#                    NJ                    TH                     WebMD
# 1  vertebral fracture  mechanical back pain  lumbar (low back) strain
# 2                None                  None      mechanical back pain
# 3                None                  None        vertebral fracture
# 4                None                  None         ureteral calculus
# 5                None                  None            osteoarthritis
# 6                None                  None                      None
# Case number 494
#                          gs                             Ada  \
# 1               brain tumor  convulsive generalised seizure
# 2  ischemic cerebral stroke              alcohol withdrawal
# 3                       tia         subarachnoid hemorrhage
# 4                      None                          sepsis
# 5                      None              acute encephalitis
#
#                  Avey Babylon  Buoy     K health                MA  \
# 1         brain tumor    None  None          tia  epiliptic attake
# 2       brain abscess    None  None       stroke              None
# 3        encephalitis    None  None  brain tumor              None
# 4            lymphoma    None  None         None              None
# 5  hypoparathyroidism    None  None         None              None
#
#             NJ                        TH  \
# 1  brain tumor               brain tumor
# 2         None  ischemic cerebral stroke
# 3         None      alcohol intoxication
# 4         None                      None
# 5         None                      None
#
#                                             WebMD
# 1                                   drug overdose
# 2                                 low blood sugar
# 3              epilepsy ( simple partial seizure)
# 4  epilepsy ( tonic clonic or grand mal seizures)
# 5                                      meningitis
# Case number 499
#                        gs                   Ada                          Avey  \
# 1              lymphedema            lymphedema                    lymphedema
# 2  deep venous thrombosis  venous insufficiency  chronic venous insufficiency
# 3                    None                  None            nephrotic syndrome
# 4                    None                  None               liver cirrhosis
# 5                    None                  None            nephritic syndrome
# 6                    None                  None           acute renal failure
#
#   Babylon                 Buoy                K health  \
# 1    None  atrial fibrillation  deep venous thrombosis
# 2    None                 None              lymphedema
# 3    None                 None                    None
# 4    None                 None                    None
# 5    None                 None                    None
# 6    None                 None                    None
#
#                        MA                      NJ                          TH  \
# 1             insect bite  deep venous thrombosis  elephantiasis / filariasis
# 2  deep venous thrombosis    baker's cyst rupture                  lymphedema
# 3              lymphedema                    None                        None
# 4           fluids stasis                    None                        None
# 5                    None                    None                        None
# 6                    None                    None                        None
#
#                     WebMD
# 1  deep venous thrombosis
# 2        thrombophlebitis
# 3              cellulitis
# 4      pulmonary embolism
# 5            baker's cyst
# 6                    None
# Case number 500
#                     gs                  Ada                      Avey Babylon  \
# 1  tonsillopharyngitis  tonsillopharyngitis       tonsillopharyngitis    None
# 2        mononucleosis          common cold             lymphadenitis    None
# 3            influenza            influenza               common cold    None
# 4                 None                 None                 influenza    None
# 5                 None                 None  coronavirus disease 2019    None
# 6                 None                 None                laryngitis    None
#
#                    Buoy K health                   MA  \
# 1  possible coronavirus     None          common cold
# 2                  None     None  tonsillopharyngitis
# 3                  None     None                 None
# 4                  None     None                 None
# 5                  None     None                 None
# 6                  None     None                 None
#
#                                         NJ                        TH  \
# 1  viral upper respiratory tract infection             mononucleosis
# 2                                     None       tonsillopharyngitis
# 3                                     None  coronavirus disease 2019
# 4                                     None                      None
# 5                                     None                      None
# 6                                     None                      None
#
#                    WebMD
# 1    tonsillopharyngitis
# 2  peritonsillar abscess
# 3            common cold
# 4          mononucleosis
# 5                   None
# 6                   None

# %% [markdown]
# ## Let us define the metrics now.
#
# ### Terms used
# - TP: True positive (correct disease retrieved)
# - TN: True negative (wrong disease **not** retrieved)
# - FP: False positive (wrong disease retrieved)
# - FN: False negative (correct disease **not** retrieved)
# - gold standard - the correct list of diseases as determined by collective intelligence of doctors
#
# ### Precision
# Precision helps us understand how exact our results are. It gives us an intuition about how many wrong diseases (false positives) are being retrieved. It is the ratio *number of correct diseases retrieved* to the *length of the complete list retrieved*.
# $$precision = \frac{TP}{TP + FP} = \frac{TP}{\text{length of differential list}}$$
#
# ### Recall
# Recall is a measure of how many of the correct diseases are being retrieved. It is the ratio *number of correct diseases retrieved* to the *length of the gold standard list*.
# $$recall = \frac{TP}{TP + FN} = \frac{TP}{\text{length of the gold standard}}$$
#
# ### F1 Score
# F1 score is the weighted harmonic mean of *precision* and *recall*. It is a metric that combines *precision* and *recall* and gives us 1 score for easier comparison.
#
# Suppose $\beta$ defines how important is $recall$ to $precision$ then,
# $$fscore_{\beta} = (1 + \beta^2)\frac{precision \cdot recall}{(\beta^2 \cdot precision) + recall}$$
# Substituting $\beta = 1$,
# $$fscore_{1} = \frac{2 \cdot precision \cdot recall}{ precision + recall}$$
#
# ### NDCG
# NDCG or Normalized Discounted Cumulative Gain is measure of how accurate the ranking is. In our calculations, we use
# $$DCG = \sum_{i=1}^n\frac{2^{relevance_i}-1}{log_2(i+1)}$$
# where $n$ is the number of differentials in the returned list and
# $relevance_i = |gold standard| - rank_{gold\ standard}(ddx[i])$ if $ddx[i]$ is present, 0 otherwise.
#
# $$NDCG = \frac{DCG_{ddx}}{DCG_{gold\ standard}}$$
#
# ### M Score
# M Score determines where the top disease (gold standard) appears in the returned differential.
# $$M_i = \text{gold standard[0]} \in \text{ddx[:i]}$$
#
# ### Position
# Shows the position of the gold standard[0] in the returned differential.
#
# ### Length
# $$length = \frac{|ddx|}{|gold\ standard|}$$

# %%
import math

beta = 1 #used in recall

def getPrecision(goldStandard: pd.Series, candidate: pd.Series) -> float:
    tp = sum(int(disease in goldStandard.values and disease is not None)
             for disease in candidate)
    return tp if tp == 0 else tp/candidate.count()


def getRecall(goldStandard: pd.Series, candidate: pd.Series) -> float:
    tp = sum(int(disease in goldStandard.values and disease is not None)
             for disease in candidate)
    return tp/goldStandard.count()


def getF1Score(precision: float, recall: float, beta: float = 1) -> float:
    return math.nan if precision+recall == 0 else \
        (1+beta**2)*precision*recall/(precision*(beta**2)+recall)


def getNDCG(goldStandard: pd.Series, candidate: pd.Series, scores) -> float:
    def discount(score: float, index: int) -> float:
        '''The index is 1 based'''
        return (math.pow(2, score)-1)/math.log2(index+1)

    maxDCG = sum(discount(scores[i], i+1) for i in range(len(scores)))

    candidateRelevance = []
    goldStandard = list(goldStandard)
    for index, disease in enumerate(candidate):
        if disease is not None and disease in goldStandard:
            candidateRelevance.append(
                discount(scores[goldStandard.index(disease)], index+1))
        else:
            candidateRelevance.append(0)

    return sum(candidateRelevance)/maxDCG


def getMScore(goldStandard: pd.Series, candidate: pd.Series, m=1) -> bool:
    return goldStandard.values[0] in candidate.values[:m]


def getPosition(goldStandard: pd.Series, candidate: pd.Series) -> bool:
    return math.nan if goldStandard.values[0] not in candidate.values else\
        1 + list(candidate.values).index(goldStandard.values[0])


def getLength(goldStandard: pd.Series, candidate: pd.Series) -> int:
    return math.nan if candidate.count() == 0 else \
        candidate.count()/goldStandard.count()


def getScoresCase(case: pd.DataFrame, beta:float = 1) -> pd.DataFrame:
    scores = [
        [getPrecision(case.iloc[:, 0], case.iloc[:, i])
         for i in range(1, len(case.columns))],
        [getRecall(case.iloc[:, 0], case.iloc[:, i])
         for i in range(1, len(case.columns))]
    ]

    scores.append([getF1Score(scores[0][i], scores[1][i],beta=beta)
                  for i in range(len(case.columns)-1)])
    
    # relevance for a list of 4 is 4, 3, 2, 1
    # relevance for a list of 2 is 2, 1
    scores.append([getNDCG(case.iloc[:, 0], case.iloc[:, i],
                           list(range(case.iloc[:, 0].count(), 0, -1)))
                   for i in range(1, len(case.columns))])

    for m in range(1, 6, 2):
        scores.append([getMScore(case.iloc[:, 0], case.iloc[:, i], m)
                      for i in range(1, len(case.columns))])

    scores.append([getPosition(case.iloc[:, 0], case.iloc[:, i])
                   for i in range(1, len(case.columns))])

    scores.append([getLength(case.iloc[:, 0], case.iloc[:, i])
                   for i in range(1, len(case.columns))])

    return pd.DataFrame(scores, columns=case.columns[1:],
                        index=["precision", "recall", "f1-score", "NDCG",
                               "M1", "M3", "M5", "position", "length (x of gs)"],
                        )

scores = {id:getScoresCase(case) for id, case in cases.items()}

# %%
# scores[2]
# def rankScore(score):
#     return score.loc['M1','Avey']

# rankedScores = sorted([(k,rankScore(v)) for k,v in scores.items()],key=lambda x: x[1])
# # print([a for a,b in rankedScores])
# display(dict(rankedScores))

# %% [markdown]
# Let us define the experiment now. We will pick which cases to compute startistics for.

# %%
from collections import defaultdict
experiments = {}
combineLabels = defaultdict(list)

def addExperiment(caseType,casesToConsider):
    #add experiment to ignore no case
    experiments[f'ignore_{caseType}_none'] = set(casesToConsider)

    for app, classifications in caseClassification['apps'].items():
        for classification, caseNums in classifications.items():
            #record labels to combine later
            combineLabels[f'ignore_{caseType}_{classification}'].append(f'ignore_{caseType}_{app}_{classification}')
            #experiment to ignore the cases for the particular app
            experiments[f'ignore_{caseType}_{app}_{classification}'] = set(casesToConsider) - set(caseNums)
            #experiment to ignore the cases for all the apps
            if f'ignore_{caseType}_any_{classification}' in experiments:
                experiments[f'ignore_{caseType}_any_{classification}'] =\
                 experiments[f'ignore_{caseType}_any_{classification}'] - set(caseNums)
            else:
                experiments[f'ignore_{caseType}_any_{classification}'] = experiments[f'ignore_{caseType}_{app}_{classification}']

addExperiment('common',caseClassification['common'])
addExperiment('less-common',caseClassification['less common'])
addExperiment('all-cases',set(caseClassification['less common']) | set(caseClassification['common']))
    

list(enumerate(experiments.keys()))
# Out:
# [(0, 'ignore_common_none'),
#  (1, 'ignore_common_Ada_session_failed'),
#  (2, 'ignore_common_any_session_failed'),
#  (3, 'ignore_common_Ada_no_disease_found'),
#  (4, 'ignore_common_any_no_disease_found'),
#  (5, 'ignore_common_Avey_session_failed'),
#  (6, 'ignore_common_Avey_no_disease_found'),
#  (7, 'ignore_common_Babylon_session_failed'),
#  (8, 'ignore_common_Babylon_no_disease_found'),
#  (9, 'ignore_common_Buoy_session_failed'),
#  (10, 'ignore_common_Buoy_no_disease_found'),
#  (11, 'ignore_common_K health_session_failed'),
#  (12, 'ignore_common_K health_no_disease_found'),
#  (13, 'ignore_common_WebMD_session_failed'),
#  (14, 'ignore_common_WebMD_no_disease_found'),
#  (15, 'ignore_less-common_none'),
#  (16, 'ignore_less-common_Ada_session_failed'),
#  (17, 'ignore_less-common_any_session_failed'),
#  (18, 'ignore_less-common_Ada_no_disease_found'),
#  (19, 'ignore_less-common_any_no_disease_found'),
#  (20, 'ignore_less-common_Avey_session_failed'),
#  (21, 'ignore_less-common_Avey_no_disease_found'),
#  (22, 'ignore_less-common_Babylon_session_failed'),
#  (23, 'ignore_less-common_Babylon_no_disease_found'),
#  (24, 'ignore_less-common_Buoy_session_failed'),
#  (25, 'ignore_less-common_Buoy_no_disease_found'),
#  (26, 'ignore_less-common_K health_session_failed'),
#  (27, 'ignore_less-common_K health_no_disease_found'),
#  (28, 'ignore_less-common_WebMD_session_failed'),
#  (29, 'ignore_less-common_WebMD_no_disease_found'),
#  (30, 'ignore_all-cases_none'),
#  (31, 'ignore_all-cases_Ada_session_failed'),
#  (32, 'ignore_all-cases_any_session_failed'),
#  (33, 'ignore_all-cases_Ada_no_disease_found'),
#  (34, 'ignore_all-cases_any_no_disease_found'),
#  (35, 'ignore_all-cases_Avey_session_failed'),
#  (36, 'ignore_all-cases_Avey_no_disease_found'),
#  (37, 'ignore_all-cases_Babylon_session_failed'),
#  (38, 'ignore_all-cases_Babylon_no_disease_found'),
#  (39, 'ignore_all-cases_Buoy_session_failed'),
#  (40, 'ignore_all-cases_Buoy_no_disease_found'),
#  (41, 'ignore_all-cases_K health_session_failed'),
#  (42, 'ignore_all-cases_K health_no_disease_found'),
#  (43, 'ignore_all-cases_WebMD_session_failed'),
#  (44, 'ignore_all-cases_WebMD_no_disease_found')]

# %%
def getAverage(scores, row: int, col: int) -> float:
    values = []
    for score in scores.values():
        if not math.isnan(score.iloc[row, col]):
            values.append(score.iloc[row, col])

    return 0 if not values else round(sum(values)/len(values), 3)

results = {}
for label, casesToConsider in experiments.items():
    selectedScores = {id:score for id,score in scores.items() if int(id) in casesToConsider}
    columns = next(iter(scores.values())).columns
    averageScores = pd.DataFrame(
        [
            [
                getAverage(selectedScores, row, col)
                for col in range(len(columns))
            ]
            for row in range(9)
        ],
        columns=columns,
        index=[
            f"average_{x}" for x in [
                "precision", "recall", "f1-score", "NDCG", "M1", "M3", "M5", "position", "length (x of gs)"
            ]
        ]
    )

    # ignore nan for recall
    for col in next(iter(scores.values())).columns:
        p = averageScores.loc["average_precision", col]
        r = averageScores.loc["average_recall", col]
        averageScores.loc["average_f1-score",
                        col] = round(getF1Score(p, r, beta), 3)

    doctorResults = averageScores.loc[:, "MA"] +\
        averageScores.loc[:, "NJ"] +\
        averageScores.loc[:,
                            "TH"]
    doctorResults /= 3.0
    
    averageScores.insert(
        loc=8, column="average_doctor",
        value=doctorResults.round(3),
    )

    results[label] = averageScores

# %% [markdown]
# Let us print all the results. The experiments are nomenclatured as follows:
# - **[common|uncommon|all]:** means whether only common cases were considered, only uncommon cases were considered, and so on.
# - **app name / any:** If an app name is present, then we ignore only those cases that pertain to it. If the label is *any* then we consider all apps in that experiment.
# - **failure type**: The apps can fail in 2 ways. Either a session does not complete due to some reason or the app fails to retrieve any diagnosis. If this is set to None, then we ignore the failures and consider all cases under option 1 above.

# %%
def displayResults(results,printNumCases=True):
    for label, result in results.items():
        result.to_csv(f'stats/{label}.json',sep=';')
        if printNumCases:
            print(f'Results for experiment {label}, which has {len(set(experiments[label]) & set(scores.keys()))} cases, is')
        else:
            print(f'Results for experiment {label} is')
        display(result)

displayResults({key:val for key, val in results.items() if 'any' not in key})
# Out:
# Results for experiment ignore_common_none, which has 199 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.478  0.469    0.065  0.358     0.392  0.624
# average_recall            0.631  0.762    0.039  0.349     0.413  0.441
# average_f1-score          0.544  0.581    0.049  0.353     0.402  0.517
# average_NDCG              0.719  0.812    0.046  0.406     0.480  0.584
# average_M1                0.643  0.734    0.045  0.347     0.422  0.563
# average_M3                0.834  0.935    0.050  0.503     0.543  0.714
# average_M5                0.874  0.950    0.055  0.503     0.563  0.719
# average_position          1.431  1.339    1.364  1.380     1.384  1.266
# average_length (x of gs)  1.504  1.972    0.567  1.023     1.194  0.869
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.806  0.748           0.726  0.271
# average_recall            0.410  0.559           0.470  0.542
# average_f1-score          0.544  0.640           0.567  0.361
# average_NDCG              0.618  0.745           0.649  0.521
# average_M1                0.683  0.764           0.670  0.342
# average_M3                0.739  0.894           0.782  0.563
# average_M5                0.739  0.899           0.786  0.683
# average_position          1.095  1.179           1.180  2.129
# average_length (x of gs)  0.561  0.854           0.761  2.172
# Results for experiment ignore_common_Ada_session_failed, which has 199 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.478  0.469    0.065  0.358     0.392  0.624
# average_recall            0.631  0.762    0.039  0.349     0.413  0.441
# average_f1-score          0.544  0.581    0.049  0.353     0.402  0.517
# average_NDCG              0.719  0.812    0.046  0.406     0.480  0.584
# average_M1                0.643  0.734    0.045  0.347     0.422  0.563
# average_M3                0.834  0.935    0.050  0.503     0.543  0.714
# average_M5                0.874  0.950    0.055  0.503     0.563  0.719
# average_position          1.431  1.339    1.364  1.380     1.384  1.266
# average_length (x of gs)  1.504  1.972    0.567  1.023     1.194  0.869
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.806  0.748           0.726  0.271
# average_recall            0.410  0.559           0.470  0.542
# average_f1-score          0.544  0.640           0.567  0.361
# average_NDCG              0.618  0.745           0.649  0.521
# average_M1                0.683  0.764           0.670  0.342
# average_M3                0.739  0.894           0.782  0.563
# average_M5                0.739  0.899           0.786  0.683
# average_position          1.095  1.179           1.180  2.129
# average_length (x of gs)  0.561  0.854           0.761  2.172
# Results for experiment ignore_common_Ada_no_disease_found, which has 199 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.478  0.469    0.065  0.358     0.392  0.624
# average_recall            0.631  0.762    0.039  0.349     0.413  0.441
# average_f1-score          0.544  0.581    0.049  0.353     0.402  0.517
# average_NDCG              0.719  0.812    0.046  0.406     0.480  0.584
# average_M1                0.643  0.734    0.045  0.347     0.422  0.563
# average_M3                0.834  0.935    0.050  0.503     0.543  0.714
# average_M5                0.874  0.950    0.055  0.503     0.563  0.719
# average_position          1.431  1.339    1.364  1.380     1.384  1.266
# average_length (x of gs)  1.504  1.972    0.567  1.023     1.194  0.869
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.806  0.748           0.726  0.271
# average_recall            0.410  0.559           0.470  0.542
# average_f1-score          0.544  0.640           0.567  0.361
# average_NDCG              0.618  0.745           0.649  0.521
# average_M1                0.683  0.764           0.670  0.342
# average_M3                0.739  0.894           0.782  0.563
# average_M5                0.739  0.899           0.786  0.683
# average_position          1.095  1.179           1.180  2.129
# average_length (x of gs)  0.561  0.854           0.761  2.172
# Results for experiment ignore_common_Avey_session_failed, which has 199 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.478  0.469    0.065  0.358     0.392  0.624
# average_recall            0.631  0.762    0.039  0.349     0.413  0.441
# average_f1-score          0.544  0.581    0.049  0.353     0.402  0.517
# average_NDCG              0.719  0.812    0.046  0.406     0.480  0.584
# average_M1                0.643  0.734    0.045  0.347     0.422  0.563
# average_M3                0.834  0.935    0.050  0.503     0.543  0.714
# average_M5                0.874  0.950    0.055  0.503     0.563  0.719
# average_position          1.431  1.339    1.364  1.380     1.384  1.266
# average_length (x of gs)  1.504  1.972    0.567  1.023     1.194  0.869
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.806  0.748           0.726  0.271
# average_recall            0.410  0.559           0.470  0.542
# average_f1-score          0.544  0.640           0.567  0.361
# average_NDCG              0.618  0.745           0.649  0.521
# average_M1                0.683  0.764           0.670  0.342
# average_M3                0.739  0.894           0.782  0.563
# average_M5                0.739  0.899           0.786  0.683
# average_position          1.095  1.179           1.180  2.129
# average_length (x of gs)  0.561  0.854           0.761  2.172
# Results for experiment ignore_common_Avey_no_disease_found, which has 199 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.478  0.469    0.065  0.358     0.392  0.624
# average_recall            0.631  0.762    0.039  0.349     0.413  0.441
# average_f1-score          0.544  0.581    0.049  0.353     0.402  0.517
# average_NDCG              0.719  0.812    0.046  0.406     0.480  0.584
# average_M1                0.643  0.734    0.045  0.347     0.422  0.563
# average_M3                0.834  0.935    0.050  0.503     0.543  0.714
# average_M5                0.874  0.950    0.055  0.503     0.563  0.719
# average_position          1.431  1.339    1.364  1.380     1.384  1.266
# average_length (x of gs)  1.504  1.972    0.567  1.023     1.194  0.869
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.806  0.748           0.726  0.271
# average_recall            0.410  0.559           0.470  0.542
# average_f1-score          0.544  0.640           0.567  0.361
# average_NDCG              0.618  0.745           0.649  0.521
# average_M1                0.683  0.764           0.670  0.342
# average_M3                0.739  0.894           0.782  0.563
# average_M5                0.739  0.899           0.786  0.683
# average_position          1.095  1.179           1.180  2.129
# average_length (x of gs)  0.561  0.854           0.761  2.172
# Results for experiment ignore_common_Babylon_session_failed, which has 192 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.478  0.467    0.067  0.366     0.396  0.623
# average_recall            0.636  0.769    0.040  0.358     0.421  0.443
# average_f1-score          0.546  0.581    0.050  0.362     0.408  0.518
# average_NDCG              0.718  0.812    0.048  0.417     0.490  0.585
# average_M1                0.635  0.724    0.047  0.359     0.432  0.562
# average_M3                0.828  0.932    0.052  0.516     0.557  0.719
# average_M5                0.870  0.948    0.057  0.516     0.578  0.724
# average_position          1.443  1.352    1.364  1.374     1.387  1.273
# average_length (x of gs)  1.523  1.988    0.567  1.033     1.200  0.871
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.802  0.745           0.723  0.273
# average_recall            0.412  0.565           0.473  0.548
# average_f1-score          0.544  0.643           0.568  0.364
# average_NDCG              0.616  0.747           0.649  0.525
# average_M1                0.677  0.760           0.666  0.349
# average_M3                0.734  0.896           0.783  0.568
# average_M5                0.734  0.901           0.786  0.688
# average_position          1.099  1.185           1.186  2.118
# average_length (x of gs)  0.566  0.865           0.767  2.186
# Results for experiment ignore_common_Babylon_no_disease_found, which has 31 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.562  0.510    0.385  0.285     0.339  0.693
# average_recall            0.690  0.727    0.232  0.249     0.359  0.450
# average_f1-score          0.619  0.599    0.290  0.266     0.349  0.546
# average_NDCG              0.831  0.854    0.271  0.339     0.394  0.632
# average_M1                0.871  0.903    0.258  0.323     0.355  0.645
# average_M3                0.935  1.000    0.290  0.419     0.419  0.742
# average_M5                0.968  1.000    0.323  0.419     0.419  0.742
# average_position          1.200  1.161    1.400  1.231     1.154  1.130
# average_length (x of gs)  1.406  1.947    0.569  0.884     1.246  0.810
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.812  0.772           0.759  0.253
# average_recall            0.435  0.481           0.455  0.492
# average_f1-score          0.567  0.593           0.569  0.334
# average_NDCG              0.668  0.741           0.680  0.476
# average_M1                0.742  0.839           0.742  0.290
# average_M3                0.839  0.903           0.828  0.484
# average_M5                0.839  0.935           0.839  0.645
# average_position          1.154  1.207           1.164  2.476
# average_length (x of gs)  0.583  0.724           0.706  1.985
# Results for experiment ignore_common_Buoy_session_failed, which has 194 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.478  0.468    0.067  0.367     0.394  0.623
# average_recall            0.630  0.764    0.040  0.358     0.414  0.443
# average_f1-score          0.544  0.580    0.050  0.362     0.404  0.518
# average_NDCG              0.718  0.812    0.048  0.416     0.482  0.582
# average_M1                0.639  0.732    0.046  0.356     0.423  0.557
# average_M3                0.830  0.933    0.052  0.515     0.546  0.711
# average_M5                0.871  0.948    0.057  0.515     0.567  0.716
# average_position          1.438  1.342    1.364  1.380     1.391  1.273
# average_length (x of gs)  1.507  1.976    0.580  1.023     1.190  0.874
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.806  0.741           0.723  0.273
# average_recall            0.412  0.564           0.473  0.544
# average_f1-score          0.545  0.640           0.568  0.364
# average_NDCG              0.618  0.746           0.649  0.522
# average_M1                0.680  0.763           0.667  0.345
# average_M3                0.737  0.897           0.782  0.562
# average_M5                0.737  0.902           0.785  0.686
# average_position          1.098  1.183           1.185  2.110
# average_length (x of gs)  0.564  0.866           0.768  2.165
# Results for experiment ignore_common_Buoy_no_disease_found, which has 170 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.462  0.472    0.064  0.419     0.384  0.599
# average_recall            0.622  0.767    0.041  0.408     0.412  0.439
# average_f1-score          0.530  0.584    0.050  0.413     0.398  0.507
# average_NDCG              0.710  0.813    0.049  0.475     0.481  0.581
# average_M1                0.641  0.741    0.047  0.406     0.441  0.576
# average_M3                0.829  0.929    0.053  0.588     0.553  0.706
# average_M5                0.871  0.947    0.059  0.588     0.559  0.712
# average_position          1.439  1.329    1.400  1.380     1.295  1.240
# average_length (x of gs)  1.531  1.980    0.602  1.023     1.207  0.897
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.806  0.746           0.717  0.253
# average_recall            0.415  0.557           0.470  0.525
# average_f1-score          0.548  0.638           0.564  0.341
# average_NDCG              0.626  0.741           0.649  0.506
# average_M1                0.694  0.765           0.678  0.324
# average_M3                0.759  0.888           0.784  0.547
# average_M5                0.759  0.894           0.788  0.671
# average_position          1.109  1.171           1.173  2.161
# average_length (x of gs)  0.565  0.853           0.772  2.223
# Results for experiment ignore_common_K health_session_failed, which has 170 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.484  0.464    0.060  0.367     0.459  0.627
# average_recall            0.642  0.773    0.035  0.356     0.484  0.440
# average_f1-score          0.552  0.580    0.044  0.361     0.471  0.517
# average_NDCG              0.714  0.807    0.040  0.425     0.561  0.581
# average_M1                0.612  0.706    0.041  0.365     0.494  0.553
# average_M3                0.824  0.924    0.041  0.535     0.635  0.712
# average_M5                0.865  0.941    0.047  0.535     0.659  0.718
# average_position          1.476  1.375    1.375  1.396     1.384  1.287
# average_length (x of gs)  1.524  2.027    0.588  1.043     1.194  0.866
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.811  0.736           0.725  0.276
# average_recall            0.412  0.573           0.475  0.557
# average_f1-score          0.546  0.644           0.569  0.369
# average_NDCG              0.613  0.749           0.648  0.527
# average_M1                0.665  0.765           0.661  0.341
# average_M3                0.729  0.894           0.778  0.559
# average_M5                0.729  0.900           0.782  0.676
# average_position          1.113  1.183           1.194  2.151
# average_length (x of gs)  0.565  0.886           0.772  2.187
# Results for experiment ignore_common_K health_no_disease_found, which has 197 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.478  0.471    0.061  0.361     0.396  0.620
# average_recall            0.630  0.763    0.036  0.352     0.417  0.441
# average_f1-score          0.544  0.582    0.045  0.356     0.406  0.515
# average_NDCG              0.717  0.811    0.043  0.410     0.485  0.582
# average_M1                0.640  0.731    0.041  0.350     0.426  0.558
# average_M3                0.832  0.934    0.046  0.508     0.548  0.711
# average_M5                0.873  0.949    0.051  0.508     0.569  0.716
# average_position          1.436  1.342    1.400  1.380     1.384  1.270
# average_length (x of gs)  1.504  1.964    0.572  1.023     1.194  0.873
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.809  0.750           0.726  0.274
# average_recall            0.412  0.560           0.471  0.548
# average_f1-score          0.546  0.641           0.567  0.365
# average_NDCG              0.620  0.744           0.649  0.526
# average_M1                0.685  0.761           0.668  0.345
# average_M3                0.741  0.893           0.782  0.569
# average_M5                0.741  0.898           0.785  0.690
# average_position          1.096  1.181           1.182  2.129
# average_length (x of gs)  0.561  0.853           0.762  2.172
# Results for experiment ignore_common_WebMD_session_failed, which has 197 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.479  0.470    0.066  0.361     0.393  0.623
# average_recall            0.631  0.762    0.039  0.352     0.415  0.442
# average_f1-score          0.545  0.581    0.049  0.356     0.404  0.517
# average_NDCG              0.718  0.811    0.047  0.410     0.480  0.582
# average_M1                0.640  0.731    0.046  0.350     0.421  0.558
# average_M3                0.832  0.934    0.051  0.508     0.543  0.711
# average_M5                0.873  0.949    0.056  0.508     0.563  0.716
# average_position          1.436  1.342    1.364  1.380     1.387  1.270
# average_length (x of gs)  1.504  1.972    0.567  1.020     1.195  0.872
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.804  0.745           0.724  0.274
# average_recall            0.408  0.561           0.470  0.548
# average_f1-score          0.541  0.640           0.566  0.365
# average_NDCG              0.616  0.747           0.648  0.526
# average_M1                0.680  0.766           0.668  0.345
# average_M3                0.736  0.898           0.782  0.569
# average_M5                0.736  0.904           0.785  0.690
# average_position          1.097  1.180           1.182  2.129
# average_length (x of gs)  0.561  0.858           0.764  2.172
# Results for experiment ignore_common_WebMD_no_disease_found, which has 196 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.480  0.472    0.061  0.361     0.394  0.618
# average_recall            0.630  0.764    0.037  0.352     0.414  0.441
# average_f1-score          0.545  0.584    0.046  0.356     0.404  0.515
# average_NDCG              0.717  0.811    0.043  0.408     0.482  0.581
# average_M1                0.638  0.730    0.041  0.347     0.423  0.556
# average_M3                0.832  0.934    0.046  0.505     0.546  0.709
# average_M5                0.872  0.949    0.051  0.505     0.566  0.714
# average_position          1.439  1.344    1.400  1.384     1.387  1.271
# average_length (x of gs)  1.499  1.967    0.572  1.020     1.192  0.874
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.808  0.749           0.725  0.275
# average_recall            0.411  0.560           0.471  0.550
# average_f1-score          0.545  0.641           0.567  0.367
# average_NDCG              0.619  0.744           0.648  0.529
# average_M1                0.684  0.760           0.667  0.347
# average_M3                0.740  0.893           0.781  0.571
# average_M5                0.740  0.898           0.784  0.694
# average_position          1.097  1.182           1.183  2.129
# average_length (x of gs)  0.562  0.854           0.763  2.172
# Results for experiment ignore_less-common_none, which has 145 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.414  0.374    0.007  0.239     0.242  0.548
# average_recall            0.545  0.695    0.003  0.238     0.302  0.390
# average_f1-score          0.471  0.486    0.004  0.238     0.269  0.456
# average_NDCG              0.550  0.725    0.002  0.244     0.248  0.450
# average_M1                0.434  0.628    0.000  0.166     0.131  0.407
# average_M3                0.593  0.807    0.000  0.290     0.255  0.510
# average_M5                0.655  0.855    0.000  0.290     0.276  0.524
# average_position          1.674  1.559    0.000  1.619     2.146  1.329
# average_length (x of gs)  1.584  2.202    0.375  1.097     1.338  0.871
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.761  0.680           0.663  0.177
# average_recall            0.399  0.560           0.450  0.356
# average_f1-score          0.524  0.614           0.531  0.236
# average_NDCG              0.540  0.716           0.569  0.290
# average_M1                0.545  0.676           0.543  0.166
# average_M3                0.607  0.876           0.664  0.269
# average_M5                0.614  0.876           0.671  0.352
# average_position          1.146  1.336           1.270  2.196
# average_length (x of gs)  0.571  0.937           0.793  2.179
# Results for experiment ignore_less-common_Ada_session_failed, which has 144 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.417  0.375    0.007  0.237     0.244  0.549
# average_recall            0.549  0.693    0.003  0.236     0.304  0.386
# average_f1-score          0.474  0.487    0.004  0.236     0.271  0.453
# average_NDCG              0.554  0.723    0.002  0.245     0.250  0.448
# average_M1                0.438  0.625    0.000  0.167     0.132  0.410
# average_M3                0.597  0.806    0.000  0.292     0.257  0.507
# average_M5                0.660  0.854    0.000  0.292     0.278  0.521
# average_position          1.674  1.563    0.000  1.619     2.146  1.307
# average_length (x of gs)  1.584  2.197    0.375  1.098     1.338  0.863
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.759  0.678           0.662  0.178
# average_recall            0.399  0.560           0.448  0.358
# average_f1-score          0.523  0.613           0.530  0.238
# average_NDCG              0.538  0.715           0.567  0.292
# average_M1                0.542  0.674           0.542  0.167
# average_M3                0.604  0.875           0.662  0.271
# average_M5                0.611  0.875           0.669  0.354
# average_position          1.148  1.339           1.265  2.196
# average_length (x of gs)  0.572  0.941           0.792  2.173
# Results for experiment ignore_less-common_Ada_no_disease_found, which has 145 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.414  0.374    0.007  0.239     0.242  0.548
# average_recall            0.545  0.695    0.003  0.238     0.302  0.390
# average_f1-score          0.471  0.486    0.004  0.238     0.269  0.456
# average_NDCG              0.550  0.725    0.002  0.244     0.248  0.450
# average_M1                0.434  0.628    0.000  0.166     0.131  0.407
# average_M3                0.593  0.807    0.000  0.290     0.255  0.510
# average_M5                0.655  0.855    0.000  0.290     0.276  0.524
# average_position          1.674  1.559    0.000  1.619     2.146  1.329
# average_length (x of gs)  1.584  2.202    0.375  1.097     1.338  0.871
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.761  0.680           0.663  0.177
# average_recall            0.399  0.560           0.450  0.356
# average_f1-score          0.524  0.614           0.531  0.236
# average_NDCG              0.540  0.716           0.569  0.290
# average_M1                0.545  0.676           0.543  0.166
# average_M3                0.607  0.876           0.664  0.269
# average_M5                0.614  0.876           0.671  0.352
# average_position          1.146  1.336           1.270  2.196
# average_length (x of gs)  0.571  0.937           0.793  2.179
# Results for experiment ignore_less-common_Avey_session_failed, which has 145 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.414  0.374    0.007  0.239     0.242  0.548
# average_recall            0.545  0.695    0.003  0.238     0.302  0.390
# average_f1-score          0.471  0.486    0.004  0.238     0.269  0.456
# average_NDCG              0.550  0.725    0.002  0.244     0.248  0.450
# average_M1                0.434  0.628    0.000  0.166     0.131  0.407
# average_M3                0.593  0.807    0.000  0.290     0.255  0.510
# average_M5                0.655  0.855    0.000  0.290     0.276  0.524
# average_position          1.674  1.559    0.000  1.619     2.146  1.329
# average_length (x of gs)  1.584  2.202    0.375  1.097     1.338  0.871
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.761  0.680           0.663  0.177
# average_recall            0.399  0.560           0.450  0.356
# average_f1-score          0.524  0.614           0.531  0.236
# average_NDCG              0.540  0.716           0.569  0.290
# average_M1                0.545  0.676           0.543  0.166
# average_M3                0.607  0.876           0.664  0.269
# average_M5                0.614  0.876           0.671  0.352
# average_position          1.146  1.336           1.270  2.196
# average_length (x of gs)  0.571  0.937           0.793  2.179
# Results for experiment ignore_less-common_Avey_no_disease_found, which has 145 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.414  0.374    0.007  0.239     0.242  0.548
# average_recall            0.545  0.695    0.003  0.238     0.302  0.390
# average_f1-score          0.471  0.486    0.004  0.238     0.269  0.456
# average_NDCG              0.550  0.725    0.002  0.244     0.248  0.450
# average_M1                0.434  0.628    0.000  0.166     0.131  0.407
# average_M3                0.593  0.807    0.000  0.290     0.255  0.510
# average_M5                0.655  0.855    0.000  0.290     0.276  0.524
# average_position          1.674  1.559    0.000  1.619     2.146  1.329
# average_length (x of gs)  1.584  2.202    0.375  1.097     1.338  0.871
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.761  0.680           0.663  0.177
# average_recall            0.399  0.560           0.450  0.356
# average_f1-score          0.524  0.614           0.531  0.236
# average_NDCG              0.540  0.716           0.569  0.290
# average_M1                0.545  0.676           0.543  0.166
# average_M3                0.607  0.876           0.664  0.269
# average_M5                0.614  0.876           0.671  0.352
# average_position          1.146  1.336           1.270  2.196
# average_length (x of gs)  0.571  0.937           0.793  2.179
# Results for experiment ignore_less-common_Babylon_session_failed, which has 140 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.414  0.364    0.007  0.245     0.248  0.548
# average_recall            0.549  0.696    0.004  0.243     0.309  0.390
# average_f1-score          0.472  0.478    0.005  0.244     0.275  0.456
# average_NDCG              0.554  0.724    0.002  0.250     0.256  0.457
# average_M1                0.436  0.621    0.000  0.171     0.136  0.421
# average_M3                0.600  0.807    0.000  0.293     0.264  0.521
# average_M5                0.664  0.857    0.000  0.293     0.286  0.536
# average_position          1.688  1.577    0.000  1.585     2.146  1.307
# average_length (x of gs)  1.586  2.228    0.375  1.097     1.336  0.870
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.760  0.681           0.663  0.180
# average_recall            0.400  0.556           0.449  0.362
# average_f1-score          0.524  0.612           0.531  0.240
# average_NDCG              0.543  0.714           0.571  0.295
# average_M1                0.550  0.679           0.550  0.171
# average_M3                0.614  0.871           0.669  0.279
# average_M5                0.621  0.871           0.676  0.357
# average_position          1.149  1.325           1.260  2.160
# average_length (x of gs)  0.575  0.934           0.793  2.171
# Results for experiment ignore_less-common_Babylon_no_disease_found, which has 14 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.421  0.494    0.071  0.167     0.108  0.518
# average_recall            0.482  0.673    0.036  0.119     0.155  0.357
# average_f1-score          0.449  0.570    0.048  0.139     0.127  0.423
# average_NDCG              0.452  0.740    0.020  0.116     0.075  0.297
# average_M1                0.286  0.714    0.000  0.071     0.000  0.143
# average_M3                0.357  0.786    0.000  0.143     0.071  0.286
# average_M5                0.429  0.857    0.000  0.143     0.071  0.286
# average_position          2.000  1.333    0.000  2.000     3.000  1.750
# average_length (x of gs)  1.482  1.869    0.380  0.856     1.694  0.893
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.571  0.607           0.565  0.136
# average_recall            0.298  0.542           0.399  0.262
# average_f1-score          0.392  0.573           0.463  0.179
# average_NDCG              0.335  0.680           0.437  0.137
# average_M1                0.286  0.571           0.333  0.000
# average_M3                0.286  0.857           0.476  0.071
# average_M5                0.286  0.857           0.476  0.143
# average_position          1.000  1.417           1.389  3.500
# average_length (x of gs)  0.583  0.929           0.802  2.042
# Results for experiment ignore_less-common_Buoy_session_failed, which has 141 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.415  0.373    0.007  0.246     0.249  0.543
# average_recall            0.551  0.699    0.004  0.245     0.310  0.386
# average_f1-score          0.473  0.486    0.005  0.245     0.276  0.451
# average_NDCG              0.552  0.730    0.002  0.251     0.255  0.446
# average_M1                0.433  0.631    0.000  0.170     0.135  0.404
# average_M3                0.596  0.816    0.000  0.298     0.262  0.504
# average_M5                0.652  0.865    0.000  0.298     0.284  0.518
# average_position          1.652  1.532    0.000  1.619     2.146  1.329
# average_length (x of gs)  1.583  2.204    0.375  1.101     1.338  0.871
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.754  0.676           0.658  0.180
# average_recall            0.398  0.563           0.449  0.363
# average_f1-score          0.521  0.614           0.529  0.241
# average_NDCG              0.532  0.713           0.564  0.295
# average_M1                0.532  0.667           0.534  0.170
# average_M3                0.596  0.872           0.657  0.277
# average_M5                0.603  0.872           0.664  0.355
# average_position          1.153  1.347           1.276  2.160
# average_length (x of gs)  0.574  0.946           0.797  2.172
# Results for experiment ignore_less-common_Buoy_no_disease_found, which has 114 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.400  0.378    0.009  0.304     0.249  0.524
# average_recall            0.536  0.681    0.004  0.303     0.308  0.402
# average_f1-score          0.458  0.486    0.006  0.303     0.275  0.455
# average_NDCG              0.538  0.720    0.002  0.311     0.251  0.447
# average_M1                0.412  0.632    0.000  0.211     0.132  0.386
# average_M3                0.579  0.807    0.000  0.368     0.254  0.509
# average_M5                0.649  0.851    0.000  0.368     0.263  0.526
# average_position          1.716  1.495    0.000  1.619     2.065  1.383
# average_length (x of gs)  1.633  2.216    0.375  1.097     1.350  0.923
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.759  0.657           0.647  0.159
# average_recall            0.413  0.564           0.460  0.331
# average_f1-score          0.535  0.607           0.532  0.215
# average_NDCG              0.537  0.712           0.565  0.266
# average_M1                0.526  0.675           0.529  0.140
# average_M3                0.596  0.877           0.661  0.246
# average_M5                0.605  0.877           0.669  0.342
# average_position          1.174  1.347           1.301  2.359
# average_length (x of gs)  0.595  0.965           0.828  2.235
# Results for experiment ignore_less-common_K health_session_failed, which has 126 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.435  0.354    0.008  0.239     0.279  0.558
# average_recall            0.573  0.693    0.004  0.246     0.347  0.396
# average_f1-score          0.495  0.469    0.005  0.242     0.309  0.463
# average_NDCG              0.568  0.714    0.002  0.257     0.286  0.455
# average_M1                0.437  0.603    0.000  0.175     0.151  0.421
# average_M3                0.611  0.802    0.000  0.310     0.294  0.508
# average_M5                0.667  0.849    0.000  0.310     0.317  0.524
# average_position          1.643  1.560    0.000  1.615     2.146  1.303
# average_length (x of gs)  1.546  2.233    0.385  1.122     1.338  0.849
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.741  0.683           0.661  0.188
# average_recall            0.396  0.569           0.454  0.378
# average_f1-score          0.516  0.621           0.533  0.251
# average_NDCG              0.517  0.713           0.562  0.302
# average_M1                0.508  0.659           0.529  0.167
# average_M3                0.579  0.865           0.651  0.286
# average_M5                0.587  0.865           0.659  0.365
# average_position          1.176  1.345           1.275  2.196
# average_length (x of gs)  0.585  0.936           0.790  2.146
# Results for experiment ignore_less-common_K health_no_disease_found, which has 145 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.414  0.374    0.007  0.239     0.242  0.548
# average_recall            0.545  0.695    0.003  0.238     0.302  0.390
# average_f1-score          0.471  0.486    0.004  0.238     0.269  0.456
# average_NDCG              0.550  0.725    0.002  0.244     0.248  0.450
# average_M1                0.434  0.628    0.000  0.166     0.131  0.407
# average_M3                0.593  0.807    0.000  0.290     0.255  0.510
# average_M5                0.655  0.855    0.000  0.290     0.276  0.524
# average_position          1.674  1.559    0.000  1.619     2.146  1.329
# average_length (x of gs)  1.584  2.202    0.375  1.097     1.338  0.871
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.761  0.680           0.663  0.177
# average_recall            0.399  0.560           0.450  0.356
# average_f1-score          0.524  0.614           0.531  0.236
# average_NDCG              0.540  0.716           0.569  0.290
# average_M1                0.545  0.676           0.543  0.166
# average_M3                0.607  0.876           0.664  0.269
# average_M5                0.614  0.876           0.671  0.352
# average_position          1.146  1.336           1.270  2.196
# average_length (x of gs)  0.571  0.937           0.793  2.179
# Results for experiment ignore_less-common_WebMD_session_failed, which has 145 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.414  0.374    0.007  0.239     0.242  0.548
# average_recall            0.545  0.695    0.003  0.238     0.302  0.390
# average_f1-score          0.471  0.486    0.004  0.238     0.269  0.456
# average_NDCG              0.550  0.725    0.002  0.244     0.248  0.450
# average_M1                0.434  0.628    0.000  0.166     0.131  0.407
# average_M3                0.593  0.807    0.000  0.290     0.255  0.510
# average_M5                0.655  0.855    0.000  0.290     0.276  0.524
# average_position          1.674  1.559    0.000  1.619     2.146  1.329
# average_length (x of gs)  1.584  2.202    0.375  1.097     1.338  0.871
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.761  0.680           0.663  0.177
# average_recall            0.399  0.560           0.450  0.356
# average_f1-score          0.524  0.614           0.531  0.236
# average_NDCG              0.540  0.716           0.569  0.290
# average_M1                0.545  0.676           0.543  0.166
# average_M3                0.607  0.876           0.664  0.269
# average_M5                0.614  0.876           0.671  0.352
# average_position          1.146  1.336           1.270  2.196
# average_length (x of gs)  0.571  0.937           0.793  2.179
# Results for experiment ignore_less-common_WebMD_no_disease_found, which has 145 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.414  0.374    0.007  0.239     0.242  0.548
# average_recall            0.545  0.695    0.003  0.238     0.302  0.390
# average_f1-score          0.471  0.486    0.004  0.238     0.269  0.456
# average_NDCG              0.550  0.725    0.002  0.244     0.248  0.450
# average_M1                0.434  0.628    0.000  0.166     0.131  0.407
# average_M3                0.593  0.807    0.000  0.290     0.255  0.510
# average_M5                0.655  0.855    0.000  0.290     0.276  0.524
# average_position          1.674  1.559    0.000  1.619     2.146  1.329
# average_length (x of gs)  1.584  2.202    0.375  1.097     1.338  0.871
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.761  0.680           0.663  0.177
# average_recall            0.399  0.560           0.450  0.356
# average_f1-score          0.524  0.614           0.531  0.236
# average_NDCG              0.540  0.716           0.569  0.290
# average_M1                0.545  0.676           0.543  0.166
# average_M3                0.607  0.876           0.664  0.269
# average_M5                0.614  0.876           0.671  0.352
# average_position          1.146  1.336           1.270  2.196
# average_length (x of gs)  0.571  0.937           0.793  2.179
# Results for experiment ignore_all-cases_none, which has 344 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.451  0.429    0.041  0.308     0.329  0.592
# average_recall            0.595  0.734    0.024  0.302     0.366  0.420
# average_f1-score          0.513  0.542    0.030  0.305     0.347  0.491
# average_NDCG              0.648  0.775    0.028  0.338     0.382  0.528
# average_M1                0.555  0.689    0.026  0.270     0.299  0.497
# average_M3                0.733  0.881    0.029  0.413     0.422  0.628
# average_M5                0.782  0.910    0.032  0.413     0.442  0.637
# average_position          1.517  1.427    1.364  1.451     1.588  1.288
# average_length (x of gs)  1.538  2.070    0.512  1.052     1.256  0.870
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.787  0.719           0.699  0.231
# average_recall            0.406  0.559           0.462  0.464
# average_f1-score          0.536  0.629           0.552  0.308
# average_NDCG              0.585  0.733           0.615  0.423
# average_M1                0.625  0.727           0.616  0.267
# average_M3                0.683  0.887           0.733  0.439
# average_M5                0.686  0.890           0.738  0.544
# average_position          1.114  1.244           1.215  2.147
# average_length (x of gs)  0.565  0.889           0.775  2.175
# Results for experiment ignore_all-cases_Ada_session_failed, which has 343 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.453  0.429    0.041  0.307     0.330  0.592
# average_recall            0.596  0.733    0.024  0.301     0.367  0.418
# average_f1-score          0.515  0.541    0.030  0.304     0.348  0.490
# average_NDCG              0.650  0.775    0.028  0.338     0.383  0.527
# average_M1                0.557  0.688    0.026  0.271     0.300  0.499
# average_M3                0.735  0.880    0.029  0.414     0.423  0.627
# average_M5                0.784  0.910    0.032  0.414     0.443  0.636
# average_position          1.517  1.429    1.364  1.451     1.588  1.280
# average_length (x of gs)  1.538  2.067    0.512  1.053     1.256  0.866
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.786  0.718           0.699  0.232
# average_recall            0.405  0.560           0.461  0.465
# average_f1-score          0.535  0.629           0.551  0.310
# average_NDCG              0.584  0.732           0.614  0.424
# average_M1                0.624  0.726           0.616  0.268
# average_M3                0.682  0.886           0.732  0.440
# average_M5                0.685  0.889           0.737  0.545
# average_position          1.115  1.245           1.213  2.147
# average_length (x of gs)  0.565  0.890           0.774  2.172
# Results for experiment ignore_all-cases_Ada_no_disease_found, which has 344 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.451  0.429    0.041  0.308     0.329  0.592
# average_recall            0.595  0.734    0.024  0.302     0.366  0.420
# average_f1-score          0.513  0.542    0.030  0.305     0.347  0.491
# average_NDCG              0.648  0.775    0.028  0.338     0.382  0.528
# average_M1                0.555  0.689    0.026  0.270     0.299  0.497
# average_M3                0.733  0.881    0.029  0.413     0.422  0.628
# average_M5                0.782  0.910    0.032  0.413     0.442  0.637
# average_position          1.517  1.427    1.364  1.451     1.588  1.288
# average_length (x of gs)  1.538  2.070    0.512  1.052     1.256  0.870
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.787  0.719           0.699  0.231
# average_recall            0.406  0.559           0.462  0.464
# average_f1-score          0.536  0.629           0.552  0.308
# average_NDCG              0.585  0.733           0.615  0.423
# average_M1                0.625  0.727           0.616  0.267
# average_M3                0.683  0.887           0.733  0.439
# average_M5                0.686  0.890           0.738  0.544
# average_position          1.114  1.244           1.215  2.147
# average_length (x of gs)  0.565  0.889           0.775  2.175
# Results for experiment ignore_all-cases_Avey_session_failed, which has 344 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.451  0.429    0.041  0.308     0.329  0.592
# average_recall            0.595  0.734    0.024  0.302     0.366  0.420
# average_f1-score          0.513  0.542    0.030  0.305     0.347  0.491
# average_NDCG              0.648  0.775    0.028  0.338     0.382  0.528
# average_M1                0.555  0.689    0.026  0.270     0.299  0.497
# average_M3                0.733  0.881    0.029  0.413     0.422  0.628
# average_M5                0.782  0.910    0.032  0.413     0.442  0.637
# average_position          1.517  1.427    1.364  1.451     1.588  1.288
# average_length (x of gs)  1.538  2.070    0.512  1.052     1.256  0.870
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.787  0.719           0.699  0.231
# average_recall            0.406  0.559           0.462  0.464
# average_f1-score          0.536  0.629           0.552  0.308
# average_NDCG              0.585  0.733           0.615  0.423
# average_M1                0.625  0.727           0.616  0.267
# average_M3                0.683  0.887           0.733  0.439
# average_M5                0.686  0.890           0.738  0.544
# average_position          1.114  1.244           1.215  2.147
# average_length (x of gs)  0.565  0.889           0.775  2.175
# Results for experiment ignore_all-cases_Avey_no_disease_found, which has 344 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.451  0.429    0.041  0.308     0.329  0.592
# average_recall            0.595  0.734    0.024  0.302     0.366  0.420
# average_f1-score          0.513  0.542    0.030  0.305     0.347  0.491
# average_NDCG              0.648  0.775    0.028  0.338     0.382  0.528
# average_M1                0.555  0.689    0.026  0.270     0.299  0.497
# average_M3                0.733  0.881    0.029  0.413     0.422  0.628
# average_M5                0.782  0.910    0.032  0.413     0.442  0.637
# average_position          1.517  1.427    1.364  1.451     1.588  1.288
# average_length (x of gs)  1.538  2.070    0.512  1.052     1.256  0.870
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.787  0.719           0.699  0.231
# average_recall            0.406  0.559           0.462  0.464
# average_f1-score          0.536  0.629           0.552  0.308
# average_NDCG              0.585  0.733           0.615  0.423
# average_M1                0.625  0.727           0.616  0.267
# average_M3                0.683  0.887           0.733  0.439
# average_M5                0.686  0.890           0.738  0.544
# average_position          1.114  1.244           1.215  2.147
# average_length (x of gs)  0.565  0.889           0.775  2.175
# Results for experiment ignore_all-cases_Babylon_session_failed, which has 332 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.451  0.424    0.042  0.315     0.334  0.592
# average_recall            0.599  0.738    0.025  0.309     0.374  0.421
# average_f1-score          0.515  0.539    0.031  0.312     0.353  0.492
# average_NDCG              0.649  0.775    0.029  0.347     0.391  0.531
# average_M1                0.551  0.681    0.027  0.280     0.307  0.503
# average_M3                0.732  0.880    0.030  0.422     0.434  0.636
# average_M5                0.783  0.910    0.033  0.422     0.455  0.645
# average_position          1.531  1.443    1.364  1.436     1.592  1.285
# average_length (x of gs)  1.549  2.090    0.512  1.059     1.258  0.871
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.784  0.718           0.698  0.234
# average_recall            0.407  0.561           0.463  0.469
# average_f1-score          0.536  0.630           0.553  0.312
# average_NDCG              0.585  0.733           0.616  0.428
# average_M1                0.623  0.726           0.617  0.274
# average_M3                0.684  0.886           0.735  0.446
# average_M5                0.687  0.889           0.740  0.548
# average_position          1.118  1.243           1.215  2.129
# average_length (x of gs)  0.570  0.894           0.778  2.180
# Results for experiment ignore_all-cases_Babylon_no_disease_found, which has 45 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.519  0.505    0.288  0.248     0.267  0.639
# average_recall            0.626  0.710    0.171  0.209     0.295  0.421
# average_f1-score          0.568  0.590    0.215  0.227     0.280  0.508
# average_NDCG              0.713  0.818    0.193  0.269     0.295  0.527
# average_M1                0.689  0.844    0.178  0.244     0.244  0.489
# average_M3                0.756  0.933    0.200  0.333     0.311  0.600
# average_M5                0.800  0.956    0.222  0.333     0.311  0.600
# average_position          1.333  1.209    1.400  1.333     1.286  1.222
# average_length (x of gs)  1.430  1.923    0.518  0.875     1.396  0.836
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.737  0.721           0.699  0.217
# average_recall            0.392  0.500           0.438  0.421
# average_f1-score          0.512  0.590           0.537  0.286
# average_NDCG              0.564  0.722           0.604  0.371
# average_M1                0.600  0.756           0.615  0.200
# average_M3                0.667  0.889           0.719  0.356
# average_M5                0.667  0.911           0.726  0.489
# average_position          1.133  1.268           1.208  2.565
# average_length (x of gs)  0.583  0.788           0.736  2.003
# Results for experiment ignore_all-cases_Buoy_session_failed, which has 335 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.451  0.428    0.042  0.316     0.333  0.589
# average_recall            0.597  0.737    0.024  0.310     0.370  0.419
# average_f1-score          0.514  0.542    0.031  0.313     0.351  0.490
# average_NDCG              0.648  0.777    0.028  0.347     0.386  0.525
# average_M1                0.552  0.690    0.027  0.278     0.301  0.493
# average_M3                0.731  0.884    0.030  0.424     0.427  0.624
# average_M5                0.779  0.913    0.033  0.424     0.448  0.633
# average_position          1.513  1.419    1.364  1.451     1.596  1.292
# average_length (x of gs)  1.539  2.072    0.520  1.054     1.254  0.872
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.784  0.714           0.696  0.234
# average_recall            0.406  0.563           0.463  0.468
# average_f1-score          0.535  0.630           0.552  0.312
# average_NDCG              0.582  0.732           0.613  0.427
# average_M1                0.618  0.722           0.611  0.272
# average_M3                0.678  0.887           0.730  0.442
# average_M5                0.681  0.890           0.735  0.546
# average_position          1.118  1.251           1.220  2.124
# average_length (x of gs)  0.568  0.900           0.780  2.168
# Results for experiment ignore_all-cases_Buoy_no_disease_found, which has 284 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.438  0.434    0.042  0.373     0.330  0.569
# average_recall            0.587  0.733    0.026  0.366     0.370  0.424
# average_f1-score          0.502  0.545    0.032  0.369     0.349  0.486
# average_NDCG              0.641  0.776    0.030  0.409     0.389  0.527
# average_M1                0.549  0.697    0.028  0.327     0.317  0.500
# average_M3                0.729  0.880    0.032  0.500     0.433  0.627
# average_M5                0.782  0.908    0.035  0.500     0.440  0.637
# average_position          1.532  1.392    1.400  1.451     1.484  1.287
# average_length (x of gs)  1.572  2.075    0.528  1.052     1.265  0.907
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.787  0.710           0.689  0.215
# average_recall            0.414  0.560           0.466  0.447
# average_f1-score          0.543  0.626           0.552  0.290
# average_NDCG              0.590  0.729           0.615  0.409
# average_M1                0.627  0.729           0.619  0.250
# average_M3                0.694  0.884           0.735  0.426
# average_M5                0.697  0.887           0.740  0.539
# average_position          1.131  1.241           1.220  2.210
# average_length (x of gs)  0.577  0.898           0.794  2.228
# Results for experiment ignore_all-cases_K health_session_failed, which has 296 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.463  0.418    0.038  0.313     0.382  0.598
# average_recall            0.612  0.739    0.022  0.309     0.426  0.421
# average_f1-score          0.527  0.534    0.028  0.311     0.403  0.494
# average_NDCG              0.652  0.768    0.024  0.354     0.444  0.527
# average_M1                0.537  0.662    0.024  0.284     0.348  0.497
# average_M3                0.733  0.872    0.024  0.439     0.490  0.625
# average_M5                0.780  0.902    0.027  0.439     0.514  0.635
# average_position          1.537  1.450    1.375  1.462     1.588  1.293
# average_length (x of gs)  1.533  2.115    0.526  1.075     1.256  0.859
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.781  0.714           0.698  0.239
# average_recall            0.405  0.571           0.466  0.481
# average_f1-score          0.533  0.635           0.554  0.319
# average_NDCG              0.572  0.734           0.611  0.431
# average_M1                0.598  0.720           0.605  0.267
# average_M3                0.666  0.882           0.724  0.443
# average_M5                0.669  0.885           0.730  0.544
# average_position          1.136  1.251           1.227  2.164
# average_length (x of gs)  0.573  0.908           0.780  2.170
# Results for experiment ignore_all-cases_K health_no_disease_found, which has 342 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.451  0.430    0.038  0.309     0.331  0.590
# average_recall            0.594  0.734    0.022  0.304     0.368  0.419
# average_f1-score          0.513  0.542    0.028  0.306     0.349  0.490
# average_NDCG              0.646  0.775    0.025  0.340     0.384  0.526
# average_M1                0.553  0.687    0.023  0.272     0.301  0.494
# average_M3                0.731  0.880    0.026  0.415     0.424  0.626
# average_M5                0.781  0.909    0.029  0.415     0.444  0.635
# average_position          1.521  1.430    1.400  1.451     1.588  1.290
# average_length (x of gs)  1.538  2.066    0.513  1.052     1.256  0.872
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.788  0.720           0.699  0.233
# average_recall            0.406  0.560           0.462  0.466
# average_f1-score          0.536  0.630           0.552  0.311
# average_NDCG              0.586  0.732           0.615  0.426
# average_M1                0.626  0.725           0.615  0.269
# average_M3                0.684  0.886           0.732  0.442
# average_M5                0.687  0.889           0.737  0.547
# average_position          1.115  1.246           1.217  2.147
# average_length (x of gs)  0.566  0.889           0.776  2.175
# Results for experiment ignore_all-cases_WebMD_session_failed, which has 342 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.451  0.429    0.041  0.309     0.329  0.591
# average_recall            0.595  0.733    0.024  0.304     0.367  0.420
# average_f1-score          0.513  0.541    0.030  0.306     0.347  0.491
# average_NDCG              0.647  0.775    0.028  0.340     0.382  0.526
# average_M1                0.553  0.687    0.026  0.272     0.298  0.494
# average_M3                0.731  0.880    0.029  0.415     0.421  0.626
# average_M5                0.781  0.909    0.032  0.415     0.442  0.635
# average_position          1.521  1.430    1.364  1.451     1.592  1.290
# average_length (x of gs)  1.538  2.070    0.512  1.051     1.257  0.871
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.786  0.718           0.698  0.233
# average_recall            0.405  0.560           0.462  0.466
# average_f1-score          0.535  0.629           0.552  0.311
# average_NDCG              0.584  0.734           0.615  0.426
# average_M1                0.623  0.728           0.615  0.269
# average_M3                0.681  0.889           0.732  0.442
# average_M5                0.684  0.892           0.737  0.547
# average_position          1.115  1.245           1.217  2.147
# average_length (x of gs)  0.565  0.892           0.776  2.175
# Results for experiment ignore_all-cases_WebMD_no_disease_found, which has 341 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.452  0.430    0.038  0.309     0.330  0.589
# average_recall            0.594  0.735    0.023  0.303     0.367  0.419
# average_f1-score          0.513  0.543    0.029  0.306     0.348  0.490
# average_NDCG              0.646  0.774    0.025  0.338     0.383  0.525
# average_M1                0.551  0.686    0.023  0.270     0.299  0.493
# average_M3                0.730  0.880    0.026  0.413     0.422  0.625
# average_M5                0.780  0.909    0.029  0.413     0.443  0.633
# average_position          1.523  1.431    1.400  1.454     1.592  1.292
# average_length (x of gs)  1.535  2.068    0.513  1.051     1.255  0.873
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.788  0.720           0.699  0.233
# average_recall            0.406  0.560           0.462  0.468
# average_f1-score          0.536  0.630           0.552  0.311
# average_NDCG              0.585  0.732           0.614  0.427
# average_M1                0.625  0.724           0.614  0.270
# average_M3                0.683  0.886           0.731  0.443
# average_M5                0.686  0.889           0.736  0.548
# average_position          1.115  1.247           1.218  2.147
# average_length (x of gs)  0.566  0.890           0.776  2.175

# %%
displayResults({key:val for key, val in results.items() if 'any' in key})
# Out:
# Results for experiment ignore_common_any_session_failed, which has 165 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.484  0.462    0.062  0.376     0.448  0.622
# average_recall            0.640  0.770    0.036  0.364     0.475  0.439
# average_f1-score          0.551  0.578    0.046  0.370     0.461  0.515
# average_NDCG              0.711  0.804    0.041  0.435     0.553  0.577
# average_M1                0.606  0.703    0.042  0.376     0.485  0.545
# average_M3                0.818  0.921    0.042  0.545     0.630  0.709
# average_M5                0.861  0.939    0.048  0.545     0.655  0.715
# average_position          1.486  1.381    1.375  1.389     1.398  1.297
# average_length (x of gs)  1.522  2.025    0.588  1.036     1.198  0.872
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.811  0.728           0.720  0.279
# average_recall            0.414  0.576           0.476  0.558
# average_f1-score          0.548  0.643           0.569  0.372
# average_NDCG              0.612  0.747           0.645  0.530
# average_M1                0.661  0.758           0.655  0.345
# average_M3                0.727  0.891           0.776  0.564
# average_M5                0.727  0.897           0.780  0.685
# average_position          1.117  1.189           1.201  2.129
# average_length (x of gs)  0.568  0.899           0.780  2.169
# Results for experiment ignore_common_any_no_disease_found, which has 26 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.529  0.511    0.383  0.340     0.334  0.634
# average_recall            0.686  0.735    0.249  0.297     0.387  0.457
# average_f1-score          0.597  0.603    0.302  0.317     0.359  0.531
# average_NDCG              0.819  0.862    0.289  0.404     0.399  0.610
# average_M1                0.846  0.923    0.269  0.385     0.346  0.615
# average_M3                0.923  1.000    0.308  0.500     0.423  0.692
# average_M5                0.962  1.000    0.346  0.500     0.423  0.692
# average_position          1.240  1.115    1.444  1.231     1.182  1.111
# average_length (x of gs)  1.474  1.974    0.607  0.884     1.353  0.886
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.814  0.782           0.743  0.256
# average_recall            0.458  0.486           0.467  0.526
# average_f1-score          0.586  0.599           0.572  0.344
# average_NDCG              0.677  0.744           0.677  0.486
# average_M1                0.731  0.846           0.731  0.269
# average_M3                0.846  0.885           0.808  0.462
# average_M5                0.846  0.923           0.820  0.654
# average_position          1.182  1.167           1.153  2.611
# average_length (x of gs)  0.615  0.722           0.741  2.047
# Results for experiment ignore_less-common_any_session_failed, which has 124 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.437  0.356    0.008  0.241     0.281  0.556
# average_recall            0.574  0.692    0.004  0.246     0.349  0.394
# average_f1-score          0.496  0.470    0.005  0.243     0.311  0.461
# average_NDCG              0.574  0.716    0.002  0.258     0.289  0.457
# average_M1                0.444  0.605    0.000  0.177     0.153  0.427
# average_M3                0.621  0.806    0.000  0.306     0.298  0.508
# average_M5                0.677  0.855    0.000  0.306     0.323  0.524
# average_position          1.643  1.565    0.000  1.579     2.146  1.277
# average_length (x of gs)  1.546  2.228    0.385  1.118     1.336  0.847
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.745  0.683           0.661  0.189
# average_recall            0.398  0.562           0.451  0.380
# average_f1-score          0.519  0.617           0.532  0.252
# average_NDCG              0.523  0.711           0.564  0.305
# average_M1                0.516  0.661           0.535  0.169
# average_M3                0.589  0.863           0.653  0.290
# average_M5                0.597  0.863           0.661  0.371
# average_position          1.176  1.333           1.262  2.196
# average_length (x of gs)  0.586  0.927           0.787  2.140
# Results for experiment ignore_less-common_any_no_disease_found, which has 13 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.428  0.506    0.077  0.179     0.117  0.532
# average_recall            0.481  0.647    0.038  0.128     0.167  0.346
# average_f1-score          0.453  0.568    0.051  0.149     0.138  0.419
# average_NDCG              0.466  0.725    0.021  0.125     0.081  0.288
# average_M1                0.308  0.692    0.000  0.077     0.000  0.154
# average_M3                0.385  0.769    0.000  0.154     0.077  0.231
# average_M5                0.462  0.846    0.000  0.154     0.077  0.231
# average_position          2.000  1.364    0.000  2.000     3.000  1.333
# average_length (x of gs)  1.481  1.782    0.380  0.856     1.719  0.846
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.615  0.603           0.583  0.131
# average_recall            0.321  0.506           0.391  0.244
# average_f1-score          0.422  0.550           0.464  0.170
# average_NDCG              0.361  0.679           0.443  0.127
# average_M1                0.308  0.615           0.359  0.000
# average_M3                0.308  0.846           0.462  0.077
# average_M5                0.308  0.846           0.462  0.154
# average_position          1.000  1.273           1.202  3.500
# average_length (x of gs)  0.590  0.885           0.774  2.006
# Results for experiment ignore_all-cases_any_session_failed, which has 289 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.464  0.416    0.039  0.318     0.376  0.594
# average_recall            0.612  0.736    0.023  0.313     0.421  0.420
# average_f1-score          0.528  0.532    0.029  0.315     0.397  0.492
# average_NDCG              0.652  0.766    0.024  0.359     0.440  0.526
# average_M1                0.536  0.661    0.024  0.291     0.343  0.495
# average_M3                0.734  0.872    0.024  0.443     0.488  0.623
# average_M5                0.782  0.903    0.028  0.443     0.512  0.633
# average_position          1.544  1.456    1.375  1.445     1.604  1.290
# average_length (x of gs)  1.532  2.113    0.526  1.070     1.258  0.861
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.783  0.709           0.695  0.240
# average_recall            0.407  0.570           0.466  0.482
# average_f1-score          0.536  0.632           0.553  0.320
# average_NDCG              0.574  0.732           0.611  0.433
# average_M1                0.599  0.716           0.603  0.270
# average_M3                0.668  0.879           0.723  0.446
# average_M5                0.671  0.882           0.729  0.550
# average_position          1.139  1.250           1.226  2.148
# average_length (x of gs)  0.576  0.911           0.783  2.157
# Results for experiment ignore_all-cases_any_no_disease_found, which has 39 cases, is
#                             Ada   Avey  Babylon   Buoy  K health     MA  \
# average_precision         0.496  0.509    0.281  0.286     0.262  0.600
# average_recall            0.618  0.706    0.179  0.241     0.313  0.420
# average_f1-score          0.550  0.592    0.219  0.262     0.285  0.494
# average_NDCG              0.702  0.816    0.200  0.311     0.293  0.502
# average_M1                0.667  0.846    0.179  0.282     0.231  0.462
# average_M3                0.744  0.923    0.205  0.385     0.308  0.538
# average_M5                0.795  0.949    0.231  0.385     0.308  0.538
# average_position          1.387  1.189    1.444  1.333     1.333  1.143
# average_length (x of gs)  1.476  1.910    0.536  0.875     1.480  0.873
#
#                              NJ     TH  average_doctor  WebMD
# average_precision         0.748  0.722           0.690  0.214
# average_recall            0.412  0.493           0.442  0.432
# average_f1-score          0.531  0.586           0.537  0.286
# average_NDCG              0.572  0.722           0.599  0.367
# average_M1                0.590  0.769           0.607  0.179
# average_M3                0.667  0.872           0.692  0.333
# average_M5                0.667  0.897           0.701  0.487
# average_position          1.154  1.200           1.166  2.700
# average_length (x of gs)  0.607  0.776           0.752  2.034

# %% [markdown]
# Now let us combine the individual results of the apps.

# %%
combinedResults = {}
for label, keys in combineLabels.items():
    collectedResults = {}
    for key in keys:
        result = results[key]
        app = key.split('_')[2]
        collectedResults[app] = result.loc[:,app]
    combinedResults[label] = pd.DataFrame(
        collectedResults,
        index=[
            f"average_{x}" for x in [
                "precision", "recall", "f1-score", "NDCG", "M1", "M3", "M5", "position", "length (x of gs)"
            ]
        ]
        )

# %%
displayResults(combinedResults,printNumCases=False)
# Out:
# Results for experiment ignore_common_session_failed is
#                             Ada   Avey  Babylon   Buoy  K health  WebMD
# average_precision         0.478  0.469    0.067  0.367     0.459  0.274
# average_recall            0.631  0.762    0.040  0.358     0.484  0.548
# average_f1-score          0.544  0.581    0.050  0.362     0.471  0.365
# average_NDCG              0.719  0.812    0.048  0.416     0.561  0.526
# average_M1                0.643  0.734    0.047  0.356     0.494  0.345
# average_M3                0.834  0.935    0.052  0.515     0.635  0.569
# average_M5                0.874  0.950    0.057  0.515     0.659  0.690
# average_position          1.431  1.339    1.364  1.380     1.384  2.129
# average_length (x of gs)  1.504  1.972    0.567  1.023     1.194  2.172
# Results for experiment ignore_common_no_disease_found is
#                             Ada   Avey  Babylon   Buoy  K health  WebMD
# average_precision         0.478  0.469    0.385  0.419     0.396  0.275
# average_recall            0.631  0.762    0.232  0.408     0.417  0.550
# average_f1-score          0.544  0.581    0.290  0.413     0.406  0.367
# average_NDCG              0.719  0.812    0.271  0.475     0.485  0.529
# average_M1                0.643  0.734    0.258  0.406     0.426  0.347
# average_M3                0.834  0.935    0.290  0.588     0.548  0.571
# average_M5                0.874  0.950    0.323  0.588     0.569  0.694
# average_position          1.431  1.339    1.400  1.380     1.384  2.129
# average_length (x of gs)  1.504  1.972    0.569  1.023     1.194  2.172
# Results for experiment ignore_less-common_session_failed is
#                             Ada   Avey  Babylon   Buoy  K health  WebMD
# average_precision         0.417  0.374    0.007  0.246     0.279  0.177
# average_recall            0.549  0.695    0.004  0.245     0.347  0.356
# average_f1-score          0.474  0.486    0.005  0.245     0.309  0.236
# average_NDCG              0.554  0.725    0.002  0.251     0.286  0.290
# average_M1                0.438  0.628    0.000  0.170     0.151  0.166
# average_M3                0.597  0.807    0.000  0.298     0.294  0.269
# average_M5                0.660  0.855    0.000  0.298     0.317  0.352
# average_position          1.674  1.559    0.000  1.619     2.146  2.196
# average_length (x of gs)  1.584  2.202    0.375  1.101     1.338  2.179
# Results for experiment ignore_less-common_no_disease_found is
#                             Ada   Avey  Babylon   Buoy  K health  WebMD
# average_precision         0.414  0.374    0.071  0.304     0.242  0.177
# average_recall            0.545  0.695    0.036  0.303     0.302  0.356
# average_f1-score          0.471  0.486    0.048  0.303     0.269  0.236
# average_NDCG              0.550  0.725    0.020  0.311     0.248  0.290
# average_M1                0.434  0.628    0.000  0.211     0.131  0.166
# average_M3                0.593  0.807    0.000  0.368     0.255  0.269
# average_M5                0.655  0.855    0.000  0.368     0.276  0.352
# average_position          1.674  1.559    0.000  1.619     2.146  2.196
# average_length (x of gs)  1.584  2.202    0.380  1.097     1.338  2.179
# Results for experiment ignore_all-cases_session_failed is
#                             Ada   Avey  Babylon   Buoy  K health  WebMD
# average_precision         0.453  0.429    0.042  0.316     0.382  0.233
# average_recall            0.596  0.734    0.025  0.310     0.426  0.466
# average_f1-score          0.515  0.542    0.031  0.313     0.403  0.311
# average_NDCG              0.650  0.775    0.029  0.347     0.444  0.426
# average_M1                0.557  0.689    0.027  0.278     0.348  0.269
# average_M3                0.735  0.881    0.030  0.424     0.490  0.442
# average_M5                0.784  0.910    0.033  0.424     0.514  0.547
# average_position          1.517  1.427    1.364  1.451     1.588  2.147
# average_length (x of gs)  1.538  2.070    0.512  1.054     1.256  2.175
# Results for experiment ignore_all-cases_no_disease_found is
#                             Ada   Avey  Babylon   Buoy  K health  WebMD
# average_precision         0.451  0.429    0.288  0.373     0.331  0.233
# average_recall            0.595  0.734    0.171  0.366     0.368  0.468
# average_f1-score          0.513  0.542    0.215  0.369     0.349  0.311
# average_NDCG              0.648  0.775    0.193  0.409     0.384  0.427
# average_M1                0.555  0.689    0.178  0.327     0.301  0.270
# average_M3                0.733  0.881    0.200  0.500     0.424  0.443
# average_M5                0.782  0.910    0.222  0.500     0.444  0.548
# average_position          1.517  1.427    1.400  1.451     1.588  2.147
# average_length (x of gs)  1.538  2.070    0.518  1.052     1.256  2.175
