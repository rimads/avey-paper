# %%
import json
import os
dir = "."


def load(filepath: str):
    with open(f"{dir}/{filepath}", "r") as file:
        return json.load(file)


files = [f for f in os.listdir(dir) if os.path.isfile(os.path.join(dir, f)) and "ipynb" not in f and "experiments" not in f]
experiments = [load(f) for f in files]
# cases

# %%
joined = [case for cases in experiments for case in cases]
joined
# Out:
# [{'case_number': '10',
#   'app': '2xccQ25Rule1',
#   'content': 'acute appendicitis; acute mesenteric ischemia; diverticulitis; acute cholecystitis; peptic ulcer disease; acute cholangitis'},
#  {'case_number': '37',
#   'app': '2xccQ25Rule1',
#   'content': 'cushing syndrome; thyroiditis; brain tumor; ovarian insufficiency; polycystic ovary syndrome; hypothyroidism'},
#  {'case_number': '189',
#   'app': '2xccQ25Rule1',
#   'content': 'bartholin gland abscess; bartholin gland cyst'},
#  {'case_number': '105',
#   'app': '2xccQ25Rule1',
#   'content': 'adrenal insufficiency; cronkhite canada syndrome; liver cirrhosis; polycystic ovary syndrome; chronic pancreatitis; endometrial cancer'},
#  {'case_number': '153',
#   'app': '2xccQ25Rule1',
#   'content': 'bacterial vaginosis; trichomoniasis; pelvic inflammatory disease; chlamydia'},
#  {'case_number': '51',
#   'app': '2xccQ25Rule1',
#   'content': 'brain tumor; thyroiditis; multiple sclerosis; acromegaly; adrenal insufficiency; hyperparathyroidism'},
#  {'case_number': '5',
#   'app': '2xccQ25Rule1',
#   'content': 'heart failure; valvular heart disease; anemia; pulmonary edema; chronic obstructive pulmonary disease; pericardial effusion'},
#  {'case_number': '101',
#   'app': '2xccQ25Rule1',
#   'content': 'pyelonephritis; acute prostatitis; cystitis; benign prostatic hyperplasia; nephrolithiasis; diverticulitis'},
#  {'case_number': '192',
#   'app': '2xccQ25Rule1',
#   'content': 'mumps; malaria; dengue fever; tonsillopharyngitis; osteomyelitis; otitis media'},
#  {'case_number': '28',
#   'app': '2xccQ25Rule1',
#   'content': 'diabetic ketoacidosis; hyperosmolar hyperglycemic nonketotic state; diabetes mellitus; polycystic kidney disease; cystitis; multiple sclerosis'},
#  {'case_number': '200',
#   'app': '2xccQ25Rule1',
#   'content': 'pericardial effusion; pulmonary embolism; pneumonia; pulmonary edema; pneumothorax; coronavirus disease 2019'},
#  {'case_number': '44',
#   'app': '2xccQ25Rule1',
#   'content': 'polycystic ovary syndrome; cushing syndrome; acne vulgaris; metabolic syndrome; nephrotic syndrome'},
#  {'case_number': '65',
#   'app': '2xccQ25Rule1',
#   'content': 'urticaria; psoriasis; atopic dermatitis; contact dermatitis; tinea versicolor; shingles'},
#  {'case_number': '196',
#   'app': '2xccQ25Rule1',
#   'content': 'fibroadenoma; galactocele; breast cancer; fibrocystic breasts'},
#  {'case_number': '19',
#   'app': '2xccQ25Rule1',
#   'content': 'food poisoning; cholera; acute viral gastroenteritis; celiac disease; acute bacterial gastroenteritis; cronkhite canada syndrome'},
#  {'case_number': '179',
#   'app': '2xccQ25Rule1',
#   'content': 'chronic pancreatitis; gastric cancer; pancreatic cancer; acute cholangitis; small bowel obstruction; myocardial infarction'},
#  {'case_number': '194',
#   'app': '2xccQ25Rule1',
#   'content': 'asthma; chronic obstructive pulmonary disease; lung cancer; valvular heart disease; pulmonary edema; foreign body aspiration'},
#  {'case_number': '129',
#   'app': '2xccQ25Rule1',
#   'content': 'bacterial conjunctivitis; blepharitis'},
#  {'case_number': '163',
#   'app': '2xccQ25Rule1',
#   'content': 'diverticulitis; irritable bowel syndrome; ovarian cancer; colonic polyps'},
#  {'case_number': '15',
#   'app': '2xccQ25Rule1',
#   'content': 'acute appendicitis; small bowel obstruction; diverticulitis; acute pancreatitis; abdominal aortic aneurysm; acute mesenteric ischemia'},
#  {'case_number': '150',
#   'app': '2xccQ25Rule1',
#   'content': 'vulvovaginal candidiasis; chlamydia; trichomoniasis; bacterial vaginosis'},
#  {'case_number': '87',
#   'app': '2xccQ25Rule1',
#   'content': 'rosacea; cushing syndrome; tinea versicolor; urticaria; psoriasis; osteomyelitis'},
#  {'case_number': '118',
#   'app': '2xccQ25Rule1',
#   'content': 'hypotension; abdominal aortic aneurysm; hypertrophic obstructive cardiomyopathy; upper gastrointestinal bleeding'},
#  {'case_number': '20',
#   'app': '2xccQ25Rule1',
#   'content': 'acanthosis nigricans; tinea versicolor; polycystic ovary syndrome; acne vulgaris; hemochromatosis; adrenal insufficiency'},
#  {'case_number': '1',
#   'app': '2xccQ25Rule1',
#   'content': 'acute bronchitis; pulmonary edema; foreign body aspiration; common cold; pericardial effusion; coronavirus disease 2019'},
#  {'case_number': '180',
#   'app': '2xccQ25Rule1',
#   'content': 'valvular heart disease; hypertrophic obstructive cardiomyopathy; heart failure; pulmonary edema; chronic obstructive pulmonary disease; pericardial effusion'},
#  {'case_number': '195',
#   'app': '2xccQ25Rule1',
#   'content': 'irritable bowel syndrome; pelvic inflammatory disease; diverticulitis; endometriosis; ovarian cancer; ectopic pregnancy'},
#  {'case_number': '122',
#   'app': '2xccQ25Rule1',
#   'content': 'pulmonary edema; acute bronchitis; foreign body aspiration; chronic obstructive pulmonary disease; asthma; pulmonary embolism'},
#  {'case_number': '176',
#   'app': '2xccQ25Rule1',
#   'content': 'tinea versicolor; leukemia; psoriasis; acute interstitial nephritis; osteomyelitis; superficial thrombophlebitis'},
#  {'case_number': '75',
#   'app': '2xccQ25Rule1',
#   'content': 'pelvic inflammatory disease; diverticulitis; endometriosis; secondary dysmenorrhea; ectopic pregnancy; acute appendicitis'},
#  {'case_number': '9',
#   'app': '2xccQ25Rule1',
#   'content': 'stable angina; unstable angina; myocardial infarction; variant angina'},
#  {'case_number': '188',
#   'app': '2xccQ25Rule1',
#   'content': 'leukemia; multiple myeloma; tonsillopharyngitis; diabetes mellitus; adrenal insufficiency; hyperthyroidism'},
#  {'case_number': '4',
#   'app': '2xccQ25Rule1',
#   'content': 'asthma; chronic obstructive pulmonary disease; acute bronchitis; pericardial effusion; valvular heart disease; heart failure'},
#  {'case_number': '187',
#   'app': '2xccQ25Rule1',
#   'content': 'hyperosmolar hyperglycemic nonketotic state; diabetes mellitus; diabetic ketoacidosis; metabolic syndrome'},
#  {'case_number': '138',
#   'app': '2xccQ25Rule1',
#   'content': 'irritable bowel syndrome; diverticulitis; pelvic inflammatory disease'},
#  {'case_number': '52',
#   'app': '2xccQ25Rule1',
#   'content': 'brucellosis; malaria; osteomyelitis; acute interstitial nephritis; dengue fever; rheumatic fever'},
#  {'case_number': '181',
#   'app': '2xccQ25Rule1',
#   'content': 'hydrocele; varicocele'},
#  {'case_number': '184', 'app': '2xccQ25Rule1', 'content': 'colonic polyps'},
#  {'case_number': '164',
#   'app': '2xccQ25Rule1',
#   'content': 'variant angina; myocardial infarction; unstable angina; stable angina; diffuse esophageal spasm; costochondritis'},
#  {'case_number': '47',
#   'app': '2xccQ25Rule1',
#   'content': 'cluster headaches; migraine; brain tumor; chronic sinusitis'},
#  {'case_number': '53',
#   'app': '2xccQ25Rule1',
#   'content': 'mononucleosis; tonsillopharyngitis; hiv infection; common cold; hodgkin lymphoma; influenza'},
#  {'case_number': '198',
#   'app': '2xccQ25Rule1',
#   'content': 'osteoarthritis; rheumatoid arthritis; systemic sclerosis; gout; anemia'},
#  {'case_number': '142',
#   'app': '2xccQ25Rule1',
#   'content': 'pneumothorax; pulmonary embolism; unstable angina; pulmonary edema; myocardial infarction; aortic dissection'},
#  {'case_number': '178',
#   'app': '2xccQ25Rule1',
#   'content': 'acute bronchitis; common cold; coronavirus disease 2019; influenza; laryngitis'},
#  {'case_number': '46',
#   'app': '2xccQ25Rule1',
#   'content': 'tension headache; brain tumor; chronic sinusitis; migraine; obstructive sleep apnea; hypertension disease'},
#  {'case_number': '183',
#   'app': '2xccQ25Rule1',
#   'content': 'achalasia; diffuse esophageal spasm; esophageal cancer; gastroesophageal reflux; gastric cancer; lung cancer'},
#  {'case_number': '40',
#   'app': '2xccQ25Rule1',
#   'content': 'acromegaly; lyme disease; osteoarthritis; brucellosis; rheumatoid arthritis; rheumatic fever'},
#  {'case_number': '170',
#   'app': '2xccQ25Rule1',
#   'content': 'cluster headaches; migraine; brain tumor; chronic sinusitis'},
#  {'case_number': '185',
#   'app': '2xccQ25Rule1',
#   'content': 'myocarditis; pericardial effusion; valvular heart disease; hypertrophic obstructive cardiomyopathy; anemia; rheumatic fever'},
#  {'case_number': '2',
#   'app': '2xccQ25Rule1',
#   'content': 'unstable angina; myocardial infarction; stable angina; variant angina; pericardial effusion; myocarditis'},
#  {'case_number': '174',
#   'app': '2xccQ25Rule1',
#   'content': 'mononucleosis; tonsillopharyngitis; hiv infection; cat scratch disease; epiglottitis; laryngitis'},
#  {'case_number': '24',
#   'app': '2xccQ25Rule1',
#   'content': 'coronavirus disease 2019; common cold; influenza; pulmonary embolism; tonsillopharyngitis; pericardial effusion'},
#  {'case_number': '35',
#   'app': '2xccQ25Rule1',
#   'content': 'celiac disease; food poisoning; acute bacterial gastroenteritis; acute viral gastroenteritis; liver cirrhosis; brain tumor'},
#  {'case_number': '103',
#   'app': '2xccQ25Rule1',
#   'content': 'celiac disease; chronic pancreatitis; cronkhite canada syndrome; multiple sclerosis; liver cirrhosis; irritable bowel syndrome'},
#  {'case_number': '102',
#   'app': '2xccQ25Rule1',
#   'content': 'unstable angina; myocardial infarction; pericardial effusion; pulmonary embolism; pneumothorax; pulmonary edema'},
#  {'case_number': '89',
#   'app': '2xccQ25Rule1',
#   'content': 'otitis media; otitis media with effusion; otitis media with tympanic membrane perforated; tonsillopharyngitis; earwax blockage'},
#  {'case_number': '126',
#   'app': '2xccQ25Rule1',
#   'content': 'pulmonary edema; heart failure; valvular heart disease; anemia; pericardial effusion; foreign body aspiration'},
#  {'case_number': '199',
#   'app': '2xccQ25Rule1',
#   'content': 'croup; epiglottitis; tonsillopharyngitis; anemia; hand foot and mouth disease; infective endocarditis'},
#  {'case_number': '165',
#   'app': '2xccQ25Rule1',
#   'content': 'adrenal insufficiency; gastric cancer; chronic pancreatitis; acanthosis nigricans; liver cirrhosis; tinea versicolor'},
#  {'case_number': '27',
#   'app': '2xccQ25Rule1',
#   'content': 'celiac disease; multiple sclerosis; cronkhite canada syndrome; adrenal insufficiency; acute renal failure; acute viral gastroenteritis'},
#  {'case_number': '64',
#   'app': '2xccQ25Rule1',
#   'content': 'systemic lupus erythematosus; infective endocarditis; variant angina; fibromyalgia; rheumatic fever'},
#  {'case_number': '167',
#   'app': '2xccQ25Rule1',
#   'content': 'breast engorgement; breast infection; galactocele; fibroadenoma; fibrocystic breasts'},
#  {'case_number': '186',
#   'app': '2xccQ25Rule1',
#   'content': 'intercostal neuralgia; unstable angina; costochondritis; myocardial infarction; pneumothorax; stable angina'},
#  {'case_number': '191', 'app': '2xccQ25Rule1', 'content': 'onychomycosis'},
#  {'case_number': '162',
#   'app': '2xccQ25Rule1',
#   'content': 'hypertrophic obstructive cardiomyopathy; valvular heart disease; aortic dissection; myocardial infarction; pneumothorax; pericardial effusion'},
#  {'case_number': '14',
#   'app': '2xccQ25Rule1',
#   'content': 'pneumonia; heart failure; chronic obstructive pulmonary disease; valvular heart disease; pericardial effusion; infective endocarditis'},
#  {'case_number': '60',
#   'app': '2xccQ25Rule1',
#   'content': 'primary dysmenorrhea; secondary dysmenorrhea; endometriosis; adenomyosis; uterine fibroids'},
#  {'case_number': '7',
#   'app': '2xccQ25Rule1',
#   'content': 'acute pericarditis; pericardial effusion; pneumothorax; pulmonary embolism; costochondritis; aortic dissection'},
#  {'case_number': '6',
#   'app': '2xccQ25Rule1',
#   'content': 'chronic obstructive pulmonary disease; asthma; valvular heart disease; heart failure; cardiac tamponade; lung cancer'},
#  {'case_number': '58',
#   'app': '2xccQ25Rule1',
#   'content': 'cystitis; chlamydia; pyelonephritis; pelvic inflammatory disease; endometriosis; trichomoniasis'},
#  {'case_number': '193',
#   'app': '2xccQ25Rule1',
#   'content': 'migraine; cluster headaches; pregnancy; brain abscess; brain tumor; meningitis'},
#  {'case_number': '182',
#   'app': '2xccQ25Rule1',
#   'content': 'valvular heart disease; chronic obstructive pulmonary disease; heart failure; pericardial effusion; asthma; lung cancer'},
#  {'case_number': '172',
#   'app': '2xccQ25Rule1',
#   'content': 'variant angina; myocardial infarction; unstable angina; stable angina'},
#  {'case_number': '145',
#   'app': '2xccQ25Rule1',
#   'content': 'acute pancreatitis; peptic ulcer disease; cholelithiasis; acute cholangitis; acute cholecystitis; small bowel obstruction'},
#  {'case_number': '155',
#   'app': '2xccQ25Rule1',
#   'content': 'otitis media; meningitis; otitis externa; otitis media with tympanic membrane perforated; otitis media with effusion; tonsillopharyngitis'},
#  {'case_number': '173',
#   'app': '2xccQ25Rule1',
#   'content': 'polycythemia vera; brain tumor; obstructive sleep apnea; hypertension disease; anemia; chronic sinusitis'},
#  {'case_number': '168',
#   'app': '2xccQ25Rule1',
#   'content': 'diaper dermatitis; urticaria; psoriasis; contact dermatitis; tinea versicolor; impetigo'},
#  {'case_number': '166',
#   'app': '2xccQ25Rule1',
#   'content': 'primary dysmenorrhea; secondary dysmenorrhea; endometriosis; adenomyosis; uterine fibroids'},
#  {'case_number': '73',
#   'app': '2xccQ25Rule1',
#   'content': 'trichomoniasis; bacterial vaginosis; vulvovaginal candidiasis; pelvic inflammatory disease; chlamydia'},
#  {'case_number': '115',
#   'app': '2xccQ25Rule1',
#   'content': 'pneumothorax; pulmonary embolism; pulmonary edema; aortic dissection; unstable angina; myocardial infarction'},
#  {'case_number': '161',
#   'app': '2xccQ25Rule1',
#   'content': 'urethritis; chlamydia; nephrolithiasis; trichomoniasis; benign prostatic hyperplasia; cystitis'},
#  {'case_number': '48',
#   'app': '2xccQ25Rule1',
#   'content': 'anal fissure; hemorrhoids'},
#  {'case_number': '82',
#   'app': '2xccQ25Rule1',
#   'content': 'allergic conjunctivitis; chalazion; viral conjunctivitis; bacterial conjunctivitis; blepharitis; nasolacrimal duct obstruction'},
#  {'case_number': '49',
#   'app': '2xccQ25Rule1',
#   'content': 'lactose intolerance; inflammatory bowel disease; celiac disease; acute viral gastroenteritis; food poisoning; chronic pancreatitis'},
#  {'case_number': '169',
#   'app': '2xccQ25Rule1',
#   'content': 'lactose intolerance; food poisoning; acute bacterial gastroenteritis; celiac disease; inflammatory bowel disease; acute viral gastroenteritis'},
#  {'case_number': '157',
#   'app': '2xccQ25Rule1',
#   'content': 'trichomoniasis; bacterial vaginosis; vulvovaginal candidiasis; pelvic inflammatory disease; chlamydia'},
#  {'case_number': '18',
#   'app': '2xccQ25Rule1',
#   'content': 'pneumonia; chronic obstructive pulmonary disease; valvular heart disease; heart failure; pericardial effusion; asthma'},
#  {'case_number': '112',
#   'app': '2xccQ25Rule1',
#   'content': 'diverticulitis; pelvic inflammatory disease; acute cholangitis; pyelonephritis; acute pancreatitis; acute cholecystitis'},
#  {'case_number': '171',
#   'app': '2xccQ25Rule1',
#   'content': 'chronic obstructive pulmonary disease; asthma; valvular heart disease; pericardial effusion; heart failure; pulmonary edema'},
#  {'case_number': '29',
#   'app': '2xccQ25Rule1',
#   'content': 'scabies; urticaria; atopic dermatitis; contact dermatitis; impetigo; psoriasis'},
#  {'case_number': '3',
#   'app': '2xccQ25Rule1',
#   'content': 'aortic dissection; unstable angina; myocardial infarction; hypertrophic obstructive cardiomyopathy; pulmonary edema; valvular heart disease'},
#  {'case_number': '197',
#   'app': '2xccQ25Rule1',
#   'content': 'fibromyalgia; acute renal failure; rhabdomyolysis; chronic pancreatitis; adrenal insufficiency; anemia'},
#  {'case_number': '127',
#   'app': '2xccQ25Rule1',
#   'content': 'unstable angina; myocardial infarction; pulmonary embolism; aortic dissection; variant angina; pneumothorax'},
#  {'case_number': '190',
#   'app': '2xccQ25Rule1',
#   'content': 'breast infection; breast engorgement; acute interstitial nephritis; osteomyelitis; tinea versicolor; psoriasis'},
#  {'case_number': '25',
#   'app': '2xccQ25Rule1',
#   'content': 'obstructive sleep apnea; nasal septum deviation; acromegaly'},
#  {'case_number': '104',
#   'app': '2xccQ25Rule1',
#   'content': 'stable angina; aortic dissection; pneumothorax; myocardial infarction; pulmonary embolism; unstable angina'},
#  {'case_number': '13',
#   'app': '2xccQ25Rule1',
#   'content': 'chronic obstructive pulmonary disease; asthma; valvular heart disease; heart failure; tuberculosis; cardiac tamponade'},
#  {'case_number': '121',
#   'app': '2xccQ25Rule1',
#   'content': 'urethritis; chlamydia; trichomoniasis; nephrolithiasis; cystitis; benign prostatic hyperplasia'},
#  {'case_number': '63',
#   'app': '2xccQ25Rule1',
#   'content': 'dengue fever; malaria; influenza; inflammatory bowel disease; peritonitis; acute bacterial gastroenteritis'},
#  {'case_number': '45',
#   'app': '2xccQ25Rule1',
#   'content': 'diabetic ketoacidosis; acute appendicitis; acute bacterial gastroenteritis; peptic ulcer disease; peritonitis; acute pancreatitis'},
#  {'case_number': '10',
#   'app': 'AveyRule1',
#   'content': 'acute appendicitis; diverticulitis; acute mesenteric ischemia; acute cholecystitis; acute cholangitis'},
#  {'case_number': '37',
#   'app': 'AveyRule1',
#   'content': 'cushing syndrome; ovarian insufficiency; thyroiditis; endometrial cancer; hypothyroidism; brain tumor'},
#  {'case_number': '189',
#   'app': 'AveyRule1',
#   'content': 'bartholin gland abscess; bartholin gland cyst'},
#  {'case_number': '105',
#   'app': 'AveyRule1',
#   'content': 'cronkhite canada syndrome; liver cirrhosis; adrenal insufficiency; leukemia; polycystic ovary syndrome; endometrial cancer'},
#  {'case_number': '153',
#   'app': 'AveyRule1',
#   'content': 'bacterial vaginosis; trichomoniasis; pelvic inflammatory disease'},
#  {'case_number': '51',
#   'app': 'AveyRule1',
#   'content': 'brain tumor; thyroiditis; multiple sclerosis; adrenal insufficiency; hyperparathyroidism; myasthenia gravis'},
#  {'case_number': '5',
#   'app': 'AveyRule1',
#   'content': 'heart failure; valvular heart disease; anemia; pulmonary edema; chronic obstructive pulmonary disease; myocarditis'},
#  {'case_number': '101',
#   'app': 'AveyRule1',
#   'content': 'acute prostatitis; pyelonephritis; cystitis; benign prostatic hyperplasia'},
#  {'case_number': '192',
#   'app': 'AveyRule1',
#   'content': 'mumps; tonsillopharyngitis; malaria; dengue fever; osteomyelitis; otitis media'},
#  {'case_number': '28',
#   'app': 'AveyRule1',
#   'content': 'diabetic ketoacidosis; hyperosmolar hyperglycemic nonketotic state; diabetes mellitus; cystitis'},
#  {'case_number': '200',
#   'app': 'AveyRule1',
#   'content': 'pulmonary embolism; pneumonia; pneumothorax; pericardial effusion; coronavirus disease 2019; pulmonary edema'},
#  {'case_number': '44',
#   'app': 'AveyRule1',
#   'content': 'polycystic ovary syndrome; cushing syndrome; metabolic syndrome; acne vulgaris'},
#  {'case_number': '65',
#   'app': 'AveyRule1',
#   'content': 'urticaria; contact dermatitis; atopic dermatitis; psoriasis; tinea versicolor'},
#  {'case_number': '196',
#   'app': 'AveyRule1',
#   'content': 'galactocele; fibroadenoma; fibrocystic breasts'},
#  {'case_number': '19',
#   'app': 'AveyRule1',
#   'content': 'cholera; food poisoning; acute viral gastroenteritis'},
#  {'case_number': '179',
#   'app': 'AveyRule1',
#   'content': 'gastric cancer; chronic pancreatitis; pancreatic cancer; myocardial infarction; acute cholangitis; esophageal cancer'},
#  {'case_number': '194',
#   'app': 'AveyRule1',
#   'content': 'asthma; chronic obstructive pulmonary disease; lung cancer; valvular heart disease; foreign body aspiration; pulmonary edema'},
#  {'case_number': '129',
#   'app': 'AveyRule1',
#   'content': 'bacterial conjunctivitis; blepharitis'},
#  {'case_number': '163',
#   'app': 'AveyRule1',
#   'content': 'diverticulitis; irritable bowel syndrome; ovarian cancer'},
#  {'case_number': '15',
#   'app': 'AveyRule1',
#   'content': 'acute appendicitis; diverticulitis; small bowel obstruction; abdominal aortic aneurysm; acute pancreatitis; acute mesenteric ischemia'},
#  {'case_number': '150',
#   'app': 'AveyRule1',
#   'content': 'vulvovaginal candidiasis; trichomoniasis; bacterial vaginosis'},
#  {'case_number': '87',
#   'app': 'AveyRule1',
#   'content': 'rosacea; urticaria; contact dermatitis; tinea versicolor; psoriasis; atopic dermatitis'},
#  {'case_number': '118', 'app': 'AveyRule1', 'content': ''},
#  {'case_number': '20',
#   'app': 'AveyRule1',
#   'content': 'acanthosis nigricans; tinea versicolor; adrenal insufficiency'},
#  {'case_number': '1',
#   'app': 'AveyRule1',
#   'content': 'acute bronchitis; pulmonary edema; foreign body aspiration; common cold; pericardial effusion; asthma'},
#  {'case_number': '180',
#   'app': 'AveyRule1',
#   'content': 'valvular heart disease; hypertrophic obstructive cardiomyopathy; pulmonary edema; chronic obstructive pulmonary disease; heart failure; pericardial effusion'},
#  {'case_number': '195',
#   'app': 'AveyRule1',
#   'content': 'irritable bowel syndrome; diverticulitis; ovarian cancer; endometriosis; ectopic pregnancy; pelvic inflammatory disease'},
#  {'case_number': '122',
#   'app': 'AveyRule1',
#   'content': 'acute bronchitis; pulmonary edema; chronic obstructive pulmonary disease; asthma; foreign body aspiration; valvular heart disease'},
#  {'case_number': '176',
#   'app': 'AveyRule1',
#   'content': 'tinea versicolor; psoriasis; superficial thrombophlebitis; measles; epiglottitis; encephalitis'},
#  {'case_number': '75',
#   'app': 'AveyRule1',
#   'content': 'pelvic inflammatory disease; diverticulitis; acute appendicitis; ectopic pregnancy; spontaneous abortion; molar pregnancy'},
#  {'case_number': '9',
#   'app': 'AveyRule1',
#   'content': 'stable angina; myocardial infarction; unstable angina; variant angina'},
#  {'case_number': '188',
#   'app': 'AveyRule1',
#   'content': 'leukemia; anemia; liver cirrhosis; celiac disease; tonsillopharyngitis; adrenal insufficiency'},
#  {'case_number': '4',
#   'app': 'AveyRule1',
#   'content': 'asthma; chronic obstructive pulmonary disease; valvular heart disease; pericardial effusion; acute bronchitis; heart failure'},
#  {'case_number': '187',
#   'app': 'AveyRule1',
#   'content': 'diabetes mellitus; hyperosmolar hyperglycemic nonketotic state; diabetic ketoacidosis; metabolic syndrome'},
#  {'case_number': '138',
#   'app': 'AveyRule1',
#   'content': 'irritable bowel syndrome; diverticulitis; ovarian cancer'},
#  {'case_number': '52',
#   'app': 'AveyRule1',
#   'content': 'malaria; brucellosis; osteomyelitis; dengue fever; influenza; viral hepatitis'},
#  {'case_number': '181',
#   'app': 'AveyRule1',
#   'content': 'hydrocele; varicocele'},
#  {'case_number': '184', 'app': 'AveyRule1', 'content': 'colonic polyps'},
#  {'case_number': '164',
#   'app': 'AveyRule1',
#   'content': 'variant angina; stable angina; diffuse esophageal spasm; myocardial infarction; unstable angina'},
#  {'case_number': '47', 'app': 'AveyRule1', 'content': 'cluster headaches'},
#  {'case_number': '53',
#   'app': 'AveyRule1',
#   'content': 'mononucleosis; tonsillopharyngitis; hiv infection; hodgkin lymphoma; leukemia; coronavirus disease 2019'},
#  {'case_number': '198',
#   'app': 'AveyRule1',
#   'content': 'gout; rheumatoid arthritis; anemia'},
#  {'case_number': '142',
#   'app': 'AveyRule1',
#   'content': 'pneumothorax; pulmonary edema; aortic dissection; unstable angina; myocardial infarction; pulmonary embolism'},
#  {'case_number': '178',
#   'app': 'AveyRule1',
#   'content': 'acute bronchitis; common cold; influenza; coronavirus disease 2019'},
#  {'case_number': '46', 'app': 'AveyRule1', 'content': 'tension headache'},
#  {'case_number': '183',
#   'app': 'AveyRule1',
#   'content': 'achalasia; diffuse esophageal spasm; esophageal cancer; gastric cancer'},
#  {'case_number': '40',
#   'app': 'AveyRule1',
#   'content': 'osteoarthritis; acromegaly; rheumatoid arthritis; rheumatic fever'},
#  {'case_number': '170',
#   'app': 'AveyRule1',
#   'content': 'cluster headaches; brain tumor; chronic sinusitis; migraine'},
#  {'case_number': '185',
#   'app': 'AveyRule1',
#   'content': 'myocarditis; pericardial effusion; rheumatic fever; valvular heart disease; hypertrophic obstructive cardiomyopathy; anemia'},
#  {'case_number': '2',
#   'app': 'AveyRule1',
#   'content': 'unstable angina; myocardial infarction; stable angina; pericardial effusion; variant angina; myocarditis'},
#  {'case_number': '174',
#   'app': 'AveyRule1',
#   'content': 'mononucleosis; tonsillopharyngitis; cat scratch disease; coronavirus disease 2019; epiglottitis'},
#  {'case_number': '24',
#   'app': 'AveyRule1',
#   'content': 'common cold; coronavirus disease 2019; influenza; tonsillopharyngitis; pericardial effusion; pneumonia'},
#  {'case_number': '35',
#   'app': 'AveyRule1',
#   'content': 'celiac disease; acute bacterial gastroenteritis; acute viral gastroenteritis; liver cirrhosis; food poisoning; small bowel obstruction'},
#  {'case_number': '103',
#   'app': 'AveyRule1',
#   'content': 'celiac disease; chronic pancreatitis; cronkhite canada syndrome; multiple sclerosis; liver cirrhosis; irritable bowel syndrome'},
#  {'case_number': '102',
#   'app': 'AveyRule1',
#   'content': 'pulmonary embolism; pneumothorax; pneumonia; unstable angina; pulmonary edema; myocardial infarction'},
#  {'case_number': '89',
#   'app': 'AveyRule1',
#   'content': 'otitis media; otitis media with effusion; otitis media with tympanic membrane perforated; tonsillopharyngitis'},
#  {'case_number': '126',
#   'app': 'AveyRule1',
#   'content': 'pulmonary edema; heart failure; valvular heart disease; anemia; coronavirus disease 2019; foreign body aspiration'},
#  {'case_number': '199',
#   'app': 'AveyRule1',
#   'content': 'epiglottitis; tonsillopharyngitis; croup; encephalitis; anemia; infective endocarditis'},
#  {'case_number': '165',
#   'app': 'AveyRule1',
#   'content': 'adrenal insufficiency; gastric cancer; chronic pancreatitis; acanthosis nigricans; tinea versicolor; cronkhite canada syndrome'},
#  {'case_number': '27',
#   'app': 'AveyRule1',
#   'content': 'celiac disease; cronkhite canada syndrome; chronic pancreatitis; adrenal insufficiency; diabetes mellitus; pancreatic cancer'},
#  {'case_number': '64',
#   'app': 'AveyRule1',
#   'content': 'systemic lupus erythematosus'},
#  {'case_number': '167',
#   'app': 'AveyRule1',
#   'content': 'breast engorgement; galactocele; fibrocystic breasts; breast infection; fibroadenoma'},
#  {'case_number': '186',
#   'app': 'AveyRule1',
#   'content': 'intercostal neuralgia; myocardial infarction; unstable angina'},
#  {'case_number': '191', 'app': 'AveyRule1', 'content': 'onychomycosis'},
#  {'case_number': '162',
#   'app': 'AveyRule1',
#   'content': 'pneumothorax; hypertrophic obstructive cardiomyopathy; aortic dissection; pulmonary embolism; valvular heart disease; chronic obstructive pulmonary disease'},
#  {'case_number': '14',
#   'app': 'AveyRule1',
#   'content': 'pneumonia; pericardial effusion; coronavirus disease 2019; pulmonary edema; pulmonary embolism; acute bronchitis'},
#  {'case_number': '60',
#   'app': 'AveyRule1',
#   'content': 'secondary dysmenorrhea; endometriosis; primary dysmenorrhea; adenomyosis; uterine fibroids'},
#  {'case_number': '7',
#   'app': 'AveyRule1',
#   'content': 'pericardial effusion; acute pericarditis; pneumothorax; pulmonary embolism; aortic dissection; costochondritis'},
#  {'case_number': '6',
#   'app': 'AveyRule1',
#   'content': 'chronic obstructive pulmonary disease; asthma; heart failure; valvular heart disease; cardiac tamponade; pericardial effusion'},
#  {'case_number': '58',
#   'app': 'AveyRule1',
#   'content': 'cystitis; pyelonephritis; nephrolithiasis; pelvic inflammatory disease; diverticulitis; urethritis'},
#  {'case_number': '193',
#   'app': 'AveyRule1',
#   'content': 'migraine; hypertension disease; cluster headaches; brain tumor; meningitis; tension headache'},
#  {'case_number': '182',
#   'app': 'AveyRule1',
#   'content': 'chronic obstructive pulmonary disease; valvular heart disease; heart failure; pericardial effusion; asthma; lung cancer'},
#  {'case_number': '172',
#   'app': 'AveyRule1',
#   'content': 'variant angina; myocardial infarction; unstable angina'},
#  {'case_number': '145',
#   'app': 'AveyRule1',
#   'content': 'acute pancreatitis; peptic ulcer disease; cholelithiasis; acute cholangitis; small bowel obstruction; acute cholecystitis'},
#  {'case_number': '155',
#   'app': 'AveyRule1',
#   'content': 'otitis media; meningitis; otitis media with effusion; otitis media with tympanic membrane perforated; otitis externa; tonsillopharyngitis'},
#  {'case_number': '173',
#   'app': 'AveyRule1',
#   'content': 'polycythemia vera; hypertension disease; migraine; tension headache'},
#  {'case_number': '168',
#   'app': 'AveyRule1',
#   'content': 'diaper dermatitis; urticaria; contact dermatitis'},
#  {'case_number': '166',
#   'app': 'AveyRule1',
#   'content': 'primary dysmenorrhea; adenomyosis; secondary dysmenorrhea; endometriosis'},
#  {'case_number': '73',
#   'app': 'AveyRule1',
#   'content': 'bacterial vaginosis; trichomoniasis; vulvovaginal candidiasis; chlamydia; pelvic inflammatory disease'},
#  {'case_number': '115',
#   'app': 'AveyRule1',
#   'content': 'pneumothorax; aortic dissection; pulmonary edema; pulmonary embolism; unstable angina; myocardial infarction'},
#  {'case_number': '161',
#   'app': 'AveyRule1',
#   'content': 'urethritis; chlamydia; trichomoniasis; benign prostatic hyperplasia'},
#  {'case_number': '48',
#   'app': 'AveyRule1',
#   'content': 'anal fissure; hemorrhoids'},
#  {'case_number': '82',
#   'app': 'AveyRule1',
#   'content': 'allergic conjunctivitis; viral conjunctivitis; chalazion; blepharitis; nasolacrimal duct obstruction'},
#  {'case_number': '49',
#   'app': 'AveyRule1',
#   'content': 'lactose intolerance; celiac disease; inflammatory bowel disease; chronic pancreatitis; acute viral gastroenteritis; acute bacterial gastroenteritis'},
#  {'case_number': '169',
#   'app': 'AveyRule1',
#   'content': 'inflammatory bowel disease; lactose intolerance; abdominal aortic aneurysm; small bowel obstruction; colonic polyps; irritable bowel syndrome'},
#  {'case_number': '157',
#   'app': 'AveyRule1',
#   'content': 'trichomoniasis; bacterial vaginosis; vulvovaginal candidiasis; pelvic inflammatory disease'},
#  {'case_number': '18',
#   'app': 'AveyRule1',
#   'content': 'pneumonia; chronic obstructive pulmonary disease; asthma; pericardial effusion; heart failure; valvular heart disease'},
#  {'case_number': '112',
#   'app': 'AveyRule1',
#   'content': 'diverticulitis; acute cholangitis; pyelonephritis; pelvic inflammatory disease; infective endocarditis; osteomyelitis'},
#  {'case_number': '171',
#   'app': 'AveyRule1',
#   'content': 'chronic obstructive pulmonary disease; asthma; valvular heart disease; pericardial effusion; heart failure; pulmonary edema'},
#  {'case_number': '29',
#   'app': 'AveyRule1',
#   'content': 'impetigo; contact dermatitis; atopic dermatitis; urticaria; measles; scabies'},
#  {'case_number': '3',
#   'app': 'AveyRule1',
#   'content': 'aortic dissection; unstable angina; myocardial infarction; pulmonary edema; valvular heart disease; pneumothorax'},
#  {'case_number': '197',
#   'app': 'AveyRule1',
#   'content': 'fibromyalgia; brucellosis; anemia; malaria; polycythemia vera'},
#  {'case_number': '127',
#   'app': 'AveyRule1',
#   'content': 'aortic dissection; unstable angina; myocardial infarction; pulmonary embolism; pneumothorax; variant angina'},
#  {'case_number': '190',
#   'app': 'AveyRule1',
#   'content': 'breast infection; acute interstitial nephritis; hiv infection; rheumatic fever; tinea versicolor; psoriasis'},
#  {'case_number': '25',
#   'app': 'AveyRule1',
#   'content': 'obstructive sleep apnea'},
#  {'case_number': '104',
#   'app': 'AveyRule1',
#   'content': 'pneumothorax; aortic dissection; myocardial infarction; pulmonary embolism; stable angina; unstable angina'},
#  {'case_number': '13',
#   'app': 'AveyRule1',
#   'content': 'chronic obstructive pulmonary disease; asthma; valvular heart disease; tuberculosis; cardiac tamponade; lung cancer'},
#  {'case_number': '121',
#   'app': 'AveyRule1',
#   'content': 'urethritis; chlamydia; trichomoniasis; benign prostatic hyperplasia; acute prostatitis; cystitis'},
#  {'case_number': '63',
#   'app': 'AveyRule1',
#   'content': 'dengue fever; malaria; influenza; acute bacterial gastroenteritis; osteomyelitis; coronavirus disease 2019'},
#  {'case_number': '45',
#   'app': 'AveyRule1',
#   'content': 'diabetic ketoacidosis; acute appendicitis; peptic ulcer disease; acute bacterial gastroenteritis; peritonitis; acute pancreatitis'},
#  {'case_number': '10',
#   'app': '2xccQ25Rule2',
#   'content': 'acute appendicitis; acute mesenteric ischemia; diverticulitis; acute cholecystitis; peptic ulcer disease; acute pancreatitis'},
#  {'case_number': '37',
#   'app': '2xccQ25Rule2',
#   'content': 'cushing syndrome; thyroiditis; brain tumor; hypothyroidism; polycystic ovary syndrome; ovarian insufficiency'},
#  {'case_number': '189',
#   'app': '2xccQ25Rule2',
#   'content': 'bartholin gland abscess; bartholin gland cyst'},
#  {'case_number': '105',
#   'app': '2xccQ25Rule2',
#   'content': 'adrenal insufficiency; cronkhite canada syndrome; liver cirrhosis; leukemia; endometrial cancer; polycystic ovary syndrome'},
#  {'case_number': '153',
#   'app': '2xccQ25Rule2',
#   'content': 'bacterial vaginosis; trichomoniasis; pelvic inflammatory disease; chlamydia'},
#  {'case_number': '51',
#   'app': '2xccQ25Rule2',
#   'content': 'multiple sclerosis; myasthenia gravis; adrenal insufficiency; polycythemia vera; thyroiditis; hyperparathyroidism'},
#  {'case_number': '5',
#   'app': '2xccQ25Rule2',
#   'content': 'heart failure; valvular heart disease; pulmonary edema; anemia; chronic obstructive pulmonary disease; pericardial effusion'},
#  {'case_number': '101',
#   'app': '2xccQ25Rule2',
#   'content': 'pyelonephritis; cystitis; acute prostatitis; benign prostatic hyperplasia; nephrolithiasis; diverticulitis'},
#  {'case_number': '192',
#   'app': '2xccQ25Rule2',
#   'content': 'tonsillopharyngitis; mumps; otitis media; dengue fever; malaria; encephalitis'},
#  {'case_number': '28',
#   'app': '2xccQ25Rule2',
#   'content': 'diabetic ketoacidosis; diabetes mellitus; hyperosmolar hyperglycemic nonketotic state; polycystic kidney disease; cystitis; multiple sclerosis'},
#  {'case_number': '200',
#   'app': '2xccQ25Rule2',
#   'content': 'pericardial effusion; pulmonary edema; valvular heart disease; pulmonary embolism; pneumothorax; acute pericarditis'},
#  {'case_number': '44',
#   'app': '2xccQ25Rule2',
#   'content': 'polycystic ovary syndrome; cushing syndrome; metabolic syndrome; acne vulgaris; nephrotic syndrome'},
#  {'case_number': '65',
#   'app': '2xccQ25Rule2',
#   'content': 'urticaria; atopic dermatitis; psoriasis; contact dermatitis; tinea versicolor; shingles'},
#  {'case_number': '196',
#   'app': '2xccQ25Rule2',
#   'content': 'fibroadenoma; galactocele; fibrocystic breasts; breast cancer'},
#  {'case_number': '19',
#   'app': '2xccQ25Rule2',
#   'content': 'food poisoning; cholera; acute viral gastroenteritis; acute bacterial gastroenteritis; celiac disease; cronkhite canada syndrome'},
#  {'case_number': '179',
#   'app': '2xccQ25Rule2',
#   'content': 'acute cholangitis; chronic pancreatitis; acute pancreatitis; gastric cancer; pancreatic cancer; cholelithiasis'},
#  {'case_number': '194',
#   'app': '2xccQ25Rule2',
#   'content': 'chronic obstructive pulmonary disease; asthma; pulmonary edema; pulmonary embolism; lung cancer; valvular heart disease'},
#  {'case_number': '129',
#   'app': '2xccQ25Rule2',
#   'content': 'bacterial conjunctivitis; blepharitis'},
#  {'case_number': '163',
#   'app': '2xccQ25Rule2',
#   'content': 'irritable bowel syndrome; diverticulitis; ovarian cancer; colonic polyps'},
#  {'case_number': '15',
#   'app': '2xccQ25Rule2',
#   'content': 'acute appendicitis; diverticulitis; small bowel obstruction; acute mesenteric ischemia; acute pancreatitis; peptic ulcer disease'},
#  {'case_number': '150',
#   'app': '2xccQ25Rule2',
#   'content': 'vulvovaginal candidiasis; trichomoniasis; bacterial vaginosis; chlamydia'},
#  {'case_number': '87',
#   'app': '2xccQ25Rule2',
#   'content': 'rosacea; tinea versicolor; psoriasis; cushing syndrome; contact dermatitis; urticaria'},
#  {'case_number': '118',
#   'app': '2xccQ25Rule2',
#   'content': 'hypotension; upper gastrointestinal bleeding; hypertrophic obstructive cardiomyopathy; abdominal aortic aneurysm'},
#  {'case_number': '20',
#   'app': '2xccQ25Rule2',
#   'content': 'acanthosis nigricans; tinea versicolor; acne vulgaris; polycystic ovary syndrome; adrenal insufficiency; hemochromatosis'},
#  {'case_number': '1',
#   'app': '2xccQ25Rule2',
#   'content': 'acute bronchitis; pulmonary edema; foreign body aspiration; common cold; asthma; chronic obstructive pulmonary disease'},
#  {'case_number': '180',
#   'app': '2xccQ25Rule2',
#   'content': 'valvular heart disease; hypertrophic obstructive cardiomyopathy; pulmonary edema; heart failure; chronic obstructive pulmonary disease; myocarditis'},
#  {'case_number': '195',
#   'app': '2xccQ25Rule2',
#   'content': 'ectopic pregnancy; pelvic inflammatory disease; irritable bowel syndrome; spontaneous abortion; molar pregnancy; cystitis'},
#  {'case_number': '122',
#   'app': '2xccQ25Rule2',
#   'content': 'pulmonary edema; asthma; chronic obstructive pulmonary disease; foreign body aspiration; acute bronchitis; valvular heart disease'},
#  {'case_number': '176',
#   'app': '2xccQ25Rule2',
#   'content': 'leukemia; measles; psoriasis; superficial thrombophlebitis; systemic lupus erythematosus; tinea versicolor'},
#  {'case_number': '75',
#   'app': '2xccQ25Rule2',
#   'content': 'pelvic inflammatory disease; ectopic pregnancy; spontaneous abortion; diverticulitis; acute appendicitis; molar pregnancy'},
#  {'case_number': '9',
#   'app': '2xccQ25Rule2',
#   'content': 'stable angina; myocardial infarction; variant angina; unstable angina'},
#  {'case_number': '188',
#   'app': '2xccQ25Rule2',
#   'content': 'leukemia; adrenal insufficiency; diabetes mellitus; celiac disease; anemia; tonsillopharyngitis'},
#  {'case_number': '4',
#   'app': '2xccQ25Rule2',
#   'content': 'asthma; chronic obstructive pulmonary disease; pericardial effusion; myocarditis; pneumonia; foreign body aspiration'},
#  {'case_number': '187',
#   'app': '2xccQ25Rule2',
#   'content': 'diabetes mellitus; hyperosmolar hyperglycemic nonketotic state; diabetic ketoacidosis; metabolic syndrome'},
#  {'case_number': '138',
#   'app': '2xccQ25Rule2',
#   'content': 'irritable bowel syndrome; diverticulitis; pelvic inflammatory disease'},
#  {'case_number': '52',
#   'app': '2xccQ25Rule2',
#   'content': 'brucellosis; malaria; osteomyelitis; infective endocarditis; influenza; rheumatic fever'},
#  {'case_number': '181',
#   'app': '2xccQ25Rule2',
#   'content': 'hydrocele; varicocele'},
#  {'case_number': '184', 'app': '2xccQ25Rule2', 'content': 'colonic polyps'},
#  {'case_number': '164',
#   'app': '2xccQ25Rule2',
#   'content': 'variant angina; stable angina; myocardial infarction; unstable angina; diffuse esophageal spasm; pericardial effusion'},
#  {'case_number': '47',
#   'app': '2xccQ25Rule2',
#   'content': 'cluster headaches; migraine; brain tumor; chronic sinusitis'},
#  {'case_number': '53',
#   'app': '2xccQ25Rule2',
#   'content': 'mononucleosis; tonsillopharyngitis; hiv infection; influenza; common cold; coronavirus disease 2019'},
#  {'case_number': '198',
#   'app': '2xccQ25Rule2',
#   'content': 'osteoarthritis; rheumatoid arthritis; systemic sclerosis; anemia; gout'},
#  {'case_number': '142',
#   'app': '2xccQ25Rule2',
#   'content': 'pneumothorax; pulmonary embolism; unstable angina; myocardial infarction; pulmonary edema; aortic dissection'},
#  {'case_number': '178',
#   'app': '2xccQ25Rule2',
#   'content': 'common cold; acute bronchitis; influenza; laryngitis; coronavirus disease 2019'},
#  {'case_number': '46',
#   'app': '2xccQ25Rule2',
#   'content': 'tension headache; brain tumor; migraine; chronic sinusitis; hypertension disease; fibromyalgia'},
#  {'case_number': '183',
#   'app': '2xccQ25Rule2',
#   'content': 'achalasia; esophageal cancer; diffuse esophageal spasm; gastroesophageal reflux; gastric cancer; lung cancer'},
#  {'case_number': '40',
#   'app': '2xccQ25Rule2',
#   'content': 'acromegaly; rheumatoid arthritis; lyme disease; osteoarthritis; polymyalgia rheumatica; brucellosis'},
#  {'case_number': '170',
#   'app': '2xccQ25Rule2',
#   'content': 'cluster headaches; migraine; chronic sinusitis; brain tumor'},
#  {'case_number': '185',
#   'app': '2xccQ25Rule2',
#   'content': 'myocarditis; pericardial effusion; valvular heart disease; hypertrophic obstructive cardiomyopathy; pulmonary edema; rheumatic fever'},
#  {'case_number': '2',
#   'app': '2xccQ25Rule2',
#   'content': 'unstable angina; myocardial infarction; stable angina; variant angina; pericardial effusion; myocarditis'},
#  {'case_number': '174',
#   'app': '2xccQ25Rule2',
#   'content': 'mononucleosis; tonsillopharyngitis; hiv infection; epiglottitis; cat scratch disease; laryngitis'},
#  {'case_number': '24',
#   'app': '2xccQ25Rule2',
#   'content': 'influenza; coronavirus disease 2019; common cold; pneumonia; tonsillopharyngitis; pericardial effusion'},
#  {'case_number': '35',
#   'app': '2xccQ25Rule2',
#   'content': 'food poisoning; acute bacterial gastroenteritis; celiac disease; liver cirrhosis; acute viral gastroenteritis; brain tumor'},
#  {'case_number': '103',
#   'app': '2xccQ25Rule2',
#   'content': 'celiac disease; chronic pancreatitis; lactose intolerance; irritable bowel syndrome; cronkhite canada syndrome; liver cirrhosis'},
#  {'case_number': '102',
#   'app': '2xccQ25Rule2',
#   'content': 'myocardial infarction; unstable angina; pulmonary edema; pericardial effusion; pneumothorax; pulmonary embolism'},
#  {'case_number': '89',
#   'app': '2xccQ25Rule2',
#   'content': 'otitis media; otitis media with effusion; tonsillopharyngitis; otitis media with tympanic membrane perforated; earwax blockage'},
#  {'case_number': '126',
#   'app': '2xccQ25Rule2',
#   'content': 'pulmonary edema; heart failure; chronic obstructive pulmonary disease; valvular heart disease; lung cancer; anemia'},
#  {'case_number': '199',
#   'app': '2xccQ25Rule2',
#   'content': 'epiglottitis; croup; tonsillopharyngitis; hand foot and mouth disease; anemia; myasthenia gravis'},
#  {'case_number': '165',
#   'app': '2xccQ25Rule2',
#   'content': 'adrenal insufficiency; hemochromatosis; tinea versicolor; acanthosis nigricans; chronic pancreatitis; pancreatic cancer'},
#  {'case_number': '27',
#   'app': '2xccQ25Rule2',
#   'content': 'multiple sclerosis; celiac disease; adrenal insufficiency; acute renal failure; cronkhite canada syndrome; polycythemia vera'},
#  {'case_number': '64',
#   'app': '2xccQ25Rule2',
#   'content': 'systemic lupus erythematosus; infective endocarditis; variant angina; fibromyalgia; rheumatic fever'},
#  {'case_number': '167',
#   'app': '2xccQ25Rule2',
#   'content': 'breast engorgement; galactocele; breast infection; fibrocystic breasts; fibroadenoma'},
#  {'case_number': '186',
#   'app': '2xccQ25Rule2',
#   'content': 'intercostal neuralgia; unstable angina; myocardial infarction; costochondritis; stable angina; pneumothorax'},
#  {'case_number': '191', 'app': '2xccQ25Rule2', 'content': 'onychomycosis'},
#  {'case_number': '162',
#   'app': '2xccQ25Rule2',
#   'content': 'pneumothorax; myocardial infarction; aortic dissection; pericardial effusion; hypertrophic obstructive cardiomyopathy; chronic obstructive pulmonary disease'},
#  {'case_number': '14',
#   'app': '2xccQ25Rule2',
#   'content': 'pneumonia; pericardial effusion; heart failure; valvular heart disease; coronavirus disease 2019; chronic obstructive pulmonary disease'},
#  {'case_number': '60',
#   'app': '2xccQ25Rule2',
#   'content': 'primary dysmenorrhea; endometriosis; secondary dysmenorrhea; adenomyosis; uterine fibroids'},
#  {'case_number': '7',
#   'app': '2xccQ25Rule2',
#   'content': 'acute pericarditis; pericardial effusion; pneumothorax; costochondritis; aortic dissection; pulmonary embolism'},
#  {'case_number': '6',
#   'app': '2xccQ25Rule2',
#   'content': 'asthma; chronic obstructive pulmonary disease; valvular heart disease; cardiac tamponade; heart failure; pericardial effusion'},
#  {'case_number': '58',
#   'app': '2xccQ25Rule2',
#   'content': 'cystitis; pyelonephritis; pelvic inflammatory disease; chlamydia; trichomoniasis; urethritis'},
#  {'case_number': '193',
#   'app': '2xccQ25Rule2',
#   'content': 'migraine; cluster headaches; brain abscess; brain tumor; meningitis; pregnancy'},
#  {'case_number': '182',
#   'app': '2xccQ25Rule2',
#   'content': 'heart failure; valvular heart disease; chronic obstructive pulmonary disease; asthma; pericardial effusion; pulmonary edema'},
#  {'case_number': '172',
#   'app': '2xccQ25Rule2',
#   'content': 'variant angina; myocardial infarction; unstable angina; stable angina'},
#  {'case_number': '145',
#   'app': '2xccQ25Rule2',
#   'content': 'acute pancreatitis; peptic ulcer disease; cholelithiasis; acute cholangitis; acute cholecystitis; small bowel obstruction'},
#  {'case_number': '155',
#   'app': '2xccQ25Rule2',
#   'content': 'otitis media; otitis externa; otitis media with tympanic membrane perforated; meningitis; otitis media with effusion; tonsillopharyngitis'},
#  {'case_number': '173',
#   'app': '2xccQ25Rule2',
#   'content': 'polycythemia vera; tension headache; brain tumor; hypertension disease; brain abscess; anemia'},
#  {'case_number': '168',
#   'app': '2xccQ25Rule2',
#   'content': 'diaper dermatitis; urticaria; contact dermatitis; psoriasis; tinea versicolor; impetigo'},
#  {'case_number': '166',
#   'app': '2xccQ25Rule2',
#   'content': 'primary dysmenorrhea; endometriosis; secondary dysmenorrhea; adenomyosis; uterine fibroids'},
#  {'case_number': '73',
#   'app': '2xccQ25Rule2',
#   'content': 'trichomoniasis; bacterial vaginosis; vulvovaginal candidiasis; pelvic inflammatory disease; chlamydia'},
#  {'case_number': '115',
#   'app': '2xccQ25Rule2',
#   'content': 'pneumothorax; myocardial infarction; unstable angina; pulmonary embolism; pulmonary edema; aortic dissection'},
#  {'case_number': '161',
#   'app': '2xccQ25Rule2',
#   'content': 'urethritis; cystitis; benign prostatic hyperplasia; chlamydia; trichomoniasis; nephrolithiasis'},
#  {'case_number': '48',
#   'app': '2xccQ25Rule2',
#   'content': 'anal fissure; hemorrhoids'},
#  {'case_number': '82',
#   'app': '2xccQ25Rule2',
#   'content': 'allergic conjunctivitis; bacterial conjunctivitis; viral conjunctivitis; chalazion; nasolacrimal duct obstruction; blepharitis'},
#  {'case_number': '49',
#   'app': '2xccQ25Rule2',
#   'content': 'lactose intolerance; celiac disease; inflammatory bowel disease; food poisoning; acute viral gastroenteritis; peritonitis'},
#  {'case_number': '169',
#   'app': '2xccQ25Rule2',
#   'content': 'lactose intolerance; food poisoning; acute bacterial gastroenteritis; celiac disease; peritonitis; inflammatory bowel disease'},
#  {'case_number': '157',
#   'app': '2xccQ25Rule2',
#   'content': 'trichomoniasis; bacterial vaginosis; vulvovaginal candidiasis; pelvic inflammatory disease; chlamydia'},
#  {'case_number': '18',
#   'app': '2xccQ25Rule2',
#   'content': 'pneumonia; asthma; pericardial effusion; chronic obstructive pulmonary disease; tuberculosis; acute bronchitis'},
#  {'case_number': '112',
#   'app': '2xccQ25Rule2',
#   'content': 'diverticulitis; pyelonephritis; acute cholangitis; infective endocarditis; encephalitis; acute pancreatitis'},
#  {'case_number': '171',
#   'app': '2xccQ25Rule2',
#   'content': 'chronic obstructive pulmonary disease; asthma; heart failure; pulmonary edema; valvular heart disease; pericardial effusion'},
#  {'case_number': '29',
#   'app': '2xccQ25Rule2',
#   'content': 'urticaria; atopic dermatitis; scabies; contact dermatitis; psoriasis; impetigo'},
#  {'case_number': '3',
#   'app': '2xccQ25Rule2',
#   'content': 'aortic dissection; myocardial infarction; unstable angina; pneumothorax; variant angina; stable angina'},
#  {'case_number': '197',
#   'app': '2xccQ25Rule2',
#   'content': 'fibromyalgia; rhabdomyolysis; brucellosis; acute renal failure; malaria; thyroiditis'},
#  {'case_number': '127',
#   'app': '2xccQ25Rule2',
#   'content': 'unstable angina; myocardial infarction; pulmonary embolism; aortic dissection; pneumothorax; stable angina'},
#  {'case_number': '190',
#   'app': '2xccQ25Rule2',
#   'content': 'breast infection; breast engorgement; acute interstitial nephritis; tinea versicolor; psoriasis; osteomyelitis'},
#  {'case_number': '25',
#   'app': '2xccQ25Rule2',
#   'content': 'obstructive sleep apnea; nasal septum deviation; acromegaly'},
#  {'case_number': '104',
#   'app': '2xccQ25Rule2',
#   'content': 'aortic dissection; stable angina; pneumothorax; myocardial infarction; unstable angina; fibromyalgia'},
# ...
#  {'case_number': '190',
#   'app': '2xccQ35Rule3a',
#   'content': 'breast infection; breast engorgement; acute interstitial nephritis'},
#  {'case_number': '25',
#   'app': '2xccQ35Rule3a',
#   'content': 'obstructive sleep apnea; nasal septum deviation; acromegaly'},
#  {'case_number': '104',
#   'app': '2xccQ35Rule3a',
#   'content': 'pneumothorax; aortic dissection; stable angina; fibromyalgia; intercostal neuralgia; pulmonary embolism'},
#  {'case_number': '13',
#   'app': '2xccQ35Rule3a',
#   'content': 'asthma; chronic obstructive pulmonary disease; heart failure; valvular heart disease; tuberculosis; cardiac tamponade'},
#  {'case_number': '121',
#   'app': '2xccQ35Rule3a',
#   'content': 'urethritis; chlamydia; trichomoniasis; cystitis; benign prostatic hyperplasia; nephrolithiasis'},
#  {'case_number': '63',
#   'app': '2xccQ35Rule3a',
#   'content': 'malaria; dengue fever; brucellosis; acute bacterial gastroenteritis; osteomyelitis; influenza'},
#  {'case_number': '45',
#   'app': '2xccQ35Rule3a',
#   'content': 'diabetic ketoacidosis; hyperosmolar hyperglycemic nonketotic state; acute appendicitis; peptic ulcer disease; peritonitis; acute bacterial gastroenteritis'},
#  {'case_number': '10',
#   'app': 'AveyRule3a',
#   'content': 'acute appendicitis; acute mesenteric ischemia; diverticulitis; acute cholecystitis; acute cholangitis'},
#  {'case_number': '37',
#   'app': 'AveyRule3a',
#   'content': 'cushing syndrome; thyroiditis; ovarian insufficiency; hypothyroidism; endometrial cancer'},
#  {'case_number': '189',
#   'app': 'AveyRule3a',
#   'content': 'bartholin gland abscess; bartholin gland cyst'},
#  {'case_number': '105',
#   'app': 'AveyRule3a',
#   'content': 'cronkhite canada syndrome; liver cirrhosis; adrenal insufficiency; leukemia; polycystic ovary syndrome'},
#  {'case_number': '153',
#   'app': 'AveyRule3a',
#   'content': 'bacterial vaginosis; trichomoniasis; pelvic inflammatory disease'},
#  {'case_number': '51',
#   'app': 'AveyRule3a',
#   'content': 'multiple sclerosis; thyroiditis; adrenal insufficiency; myasthenia gravis; brain tumor; hyperparathyroidism'},
#  {'case_number': '5',
#   'app': 'AveyRule3a',
#   'content': 'heart failure; valvular heart disease; pulmonary edema; anemia; chronic obstructive pulmonary disease'},
#  {'case_number': '101',
#   'app': 'AveyRule3a',
#   'content': 'pyelonephritis; acute prostatitis; cystitis; benign prostatic hyperplasia'},
#  {'case_number': '192',
#   'app': 'AveyRule3a',
#   'content': 'mumps; tonsillopharyngitis; otitis media; dengue fever; malaria; osteomyelitis'},
#  {'case_number': '28',
#   'app': 'AveyRule3a',
#   'content': 'hyperosmolar hyperglycemic nonketotic state; diabetic ketoacidosis; diabetes mellitus; cystitis'},
#  {'case_number': '200',
#   'app': 'AveyRule3a',
#   'content': 'pulmonary embolism; pneumothorax; pneumonia; pericardial effusion; pulmonary edema; coronavirus disease 2019'},
#  {'case_number': '44',
#   'app': 'AveyRule3a',
#   'content': 'polycystic ovary syndrome; cushing syndrome; metabolic syndrome; acne vulgaris'},
#  {'case_number': '65',
#   'app': 'AveyRule3a',
#   'content': 'urticaria; contact dermatitis; atopic dermatitis; psoriasis; tinea versicolor'},
#  {'case_number': '196',
#   'app': 'AveyRule3a',
#   'content': 'fibroadenoma; galactocele; fibrocystic breasts'},
#  {'case_number': '19',
#   'app': 'AveyRule3a',
#   'content': 'cholera; food poisoning; acute viral gastroenteritis'},
#  {'case_number': '179',
#   'app': 'AveyRule3a',
#   'content': 'gastric cancer; acute cholangitis; chronic pancreatitis; pancreatic cancer; myocardial infarction'},
#  {'case_number': '194',
#   'app': 'AveyRule3a',
#   'content': 'chronic obstructive pulmonary disease; asthma; pulmonary edema; lung cancer; foreign body aspiration; valvular heart disease'},
#  {'case_number': '129',
#   'app': 'AveyRule3a',
#   'content': 'bacterial conjunctivitis; blepharitis'},
#  {'case_number': '163',
#   'app': 'AveyRule3a',
#   'content': 'irritable bowel syndrome; diverticulitis; ovarian cancer'},
#  {'case_number': '15',
#   'app': 'AveyRule3a',
#   'content': 'acute appendicitis; acute mesenteric ischemia; diverticulitis; abdominal aortic aneurysm; small bowel obstruction; acute pancreatitis'},
#  {'case_number': '150',
#   'app': 'AveyRule3a',
#   'content': 'vulvovaginal candidiasis; trichomoniasis; bacterial vaginosis'},
#  {'case_number': '87',
#   'app': 'AveyRule3a',
#   'content': 'rosacea; contact dermatitis; urticaria; tinea versicolor'},
#  {'case_number': '118', 'app': 'AveyRule3a', 'content': ''},
#  {'case_number': '20',
#   'app': 'AveyRule3a',
#   'content': 'acanthosis nigricans; tinea versicolor; adrenal insufficiency'},
#  {'case_number': '1',
#   'app': 'AveyRule3a',
#   'content': 'acute bronchitis; pulmonary edema; common cold; foreign body aspiration; pericardial effusion'},
#  {'case_number': '180',
#   'app': 'AveyRule3a',
#   'content': 'valvular heart disease; hypertrophic obstructive cardiomyopathy; pulmonary edema; chronic obstructive pulmonary disease; heart failure; pericardial effusion'},
#  {'case_number': '195',
#   'app': 'AveyRule3a',
#   'content': 'irritable bowel syndrome; ectopic pregnancy; diverticulitis; ovarian cancer; pelvic inflammatory disease; endometriosis'},
#  {'case_number': '122',
#   'app': 'AveyRule3a',
#   'content': 'chronic obstructive pulmonary disease; pulmonary edema; asthma; acute bronchitis; valvular heart disease; foreign body aspiration'},
#  {'case_number': '176',
#   'app': 'AveyRule3a',
#   'content': 'psoriasis; superficial thrombophlebitis; tinea versicolor'},
#  {'case_number': '75',
#   'app': 'AveyRule3a',
#   'content': 'pelvic inflammatory disease; ectopic pregnancy; acute appendicitis; diverticulitis'},
#  {'case_number': '9',
#   'app': 'AveyRule3a',
#   'content': 'stable angina; myocardial infarction; variant angina; unstable angina'},
#  {'case_number': '188',
#   'app': 'AveyRule3a',
#   'content': 'leukemia; anemia; celiac disease; liver cirrhosis; tonsillopharyngitis'},
#  {'case_number': '4',
#   'app': 'AveyRule3a',
#   'content': 'asthma; chronic obstructive pulmonary disease; valvular heart disease; pericardial effusion; acute bronchitis; heart failure'},
#  {'case_number': '187',
#   'app': 'AveyRule3a',
#   'content': 'diabetes mellitus; hyperosmolar hyperglycemic nonketotic state; diabetic ketoacidosis; metabolic syndrome'},
#  {'case_number': '138',
#   'app': 'AveyRule3a',
#   'content': 'irritable bowel syndrome; diverticulitis; ovarian cancer'},
#  {'case_number': '52',
#   'app': 'AveyRule3a',
#   'content': 'malaria; brucellosis; osteomyelitis; influenza; dengue fever; viral hepatitis'},
#  {'case_number': '181',
#   'app': 'AveyRule3a',
#   'content': 'hydrocele; varicocele'},
#  {'case_number': '184', 'app': 'AveyRule3a', 'content': 'colonic polyps'},
#  {'case_number': '164',
#   'app': 'AveyRule3a',
#   'content': 'variant angina; stable angina; diffuse esophageal spasm; myocardial infarction'},
#  {'case_number': '47', 'app': 'AveyRule3a', 'content': 'cluster headaches'},
#  {'case_number': '53',
#   'app': 'AveyRule3a',
#   'content': 'mononucleosis; tonsillopharyngitis; hiv infection; hodgkin lymphoma; leukemia'},
#  {'case_number': '198',
#   'app': 'AveyRule3a',
#   'content': 'rheumatoid arthritis; gout; anemia'},
#  {'case_number': '142',
#   'app': 'AveyRule3a',
#   'content': 'pneumothorax; unstable angina; myocardial infarction; aortic dissection; pulmonary edema; pulmonary embolism'},
#  {'case_number': '178',
#   'app': 'AveyRule3a',
#   'content': 'common cold; acute bronchitis; influenza; coronavirus disease 2019'},
#  {'case_number': '46', 'app': 'AveyRule3a', 'content': 'tension headache'},
#  {'case_number': '183',
#   'app': 'AveyRule3a',
#   'content': 'achalasia; diffuse esophageal spasm; esophageal cancer; gastric cancer'},
#  {'case_number': '40',
#   'app': 'AveyRule3a',
#   'content': 'rheumatoid arthritis; acromegaly; osteoarthritis'},
#  {'case_number': '170',
#   'app': 'AveyRule3a',
#   'content': 'cluster headaches; migraine; chronic sinusitis; brain tumor'},
#  {'case_number': '185',
#   'app': 'AveyRule3a',
#   'content': 'myocarditis; pericardial effusion; valvular heart disease; rheumatic fever; hypertrophic obstructive cardiomyopathy; anemia'},
#  {'case_number': '2',
#   'app': 'AveyRule3a',
#   'content': 'myocardial infarction; stable angina; unstable angina; variant angina; pericardial effusion; myocarditis'},
#  {'case_number': '174',
#   'app': 'AveyRule3a',
#   'content': 'mononucleosis; tonsillopharyngitis; cat scratch disease; coronavirus disease 2019'},
#  {'case_number': '24',
#   'app': 'AveyRule3a',
#   'content': 'influenza; common cold; coronavirus disease 2019; pneumonia; tonsillopharyngitis; pericardial effusion'},
#  {'case_number': '35',
#   'app': 'AveyRule3a',
#   'content': 'celiac disease; acute bacterial gastroenteritis; acute viral gastroenteritis; liver cirrhosis; food poisoning'},
#  {'case_number': '103',
#   'app': 'AveyRule3a',
#   'content': 'celiac disease; chronic pancreatitis; cronkhite canada syndrome; irritable bowel syndrome; multiple sclerosis; liver cirrhosis'},
#  {'case_number': '102',
#   'app': 'AveyRule3a',
#   'content': 'pneumothorax; pulmonary embolism; myocardial infarction; unstable angina; pulmonary edema; pneumonia'},
#  {'case_number': '89',
#   'app': 'AveyRule3a',
#   'content': 'otitis media; otitis media with effusion; otitis media with tympanic membrane perforated; tonsillopharyngitis'},
#  {'case_number': '126',
#   'app': 'AveyRule3a',
#   'content': 'pulmonary edema; heart failure; valvular heart disease; anemia; coronavirus disease 2019'},
#  {'case_number': '199',
#   'app': 'AveyRule3a',
#   'content': 'croup; epiglottitis; tonsillopharyngitis'},
#  {'case_number': '165',
#   'app': 'AveyRule3a',
#   'content': 'adrenal insufficiency; chronic pancreatitis; gastric cancer; tinea versicolor; acanthosis nigricans; cronkhite canada syndrome'},
#  {'case_number': '27',
#   'app': 'AveyRule3a',
#   'content': 'celiac disease; cronkhite canada syndrome; adrenal insufficiency; chronic pancreatitis; pancreatic cancer; diabetes mellitus'},
#  {'case_number': '64',
#   'app': 'AveyRule3a',
#   'content': 'systemic lupus erythematosus'},
#  {'case_number': '167',
#   'app': 'AveyRule3a',
#   'content': 'breast engorgement; galactocele; breast infection; fibrocystic breasts; fibroadenoma'},
#  {'case_number': '186',
#   'app': 'AveyRule3a',
#   'content': 'intercostal neuralgia; myocardial infarction; unstable angina'},
#  {'case_number': '191', 'app': 'AveyRule3a', 'content': 'onychomycosis'},
#  {'case_number': '162',
#   'app': 'AveyRule3a',
#   'content': 'pneumothorax; chronic obstructive pulmonary disease; pulmonary embolism; hypertrophic obstructive cardiomyopathy; aortic dissection; valvular heart disease'},
#  {'case_number': '14',
#   'app': 'AveyRule3a',
#   'content': 'coronavirus disease 2019; pericardial effusion; pneumonia; pulmonary edema; pulmonary embolism; acute bronchitis'},
#  {'case_number': '60',
#   'app': 'AveyRule3a',
#   'content': 'primary dysmenorrhea; secondary dysmenorrhea; endometriosis; adenomyosis; uterine fibroids'},
#  {'case_number': '7',
#   'app': 'AveyRule3a',
#   'content': 'acute pericarditis; pericardial effusion; pneumothorax; aortic dissection; pulmonary embolism; costochondritis'},
#  {'case_number': '6',
#   'app': 'AveyRule3a',
#   'content': 'chronic obstructive pulmonary disease; asthma; heart failure; cardiac tamponade; pericardial effusion; valvular heart disease'},
#  {'case_number': '58',
#   'app': 'AveyRule3a',
#   'content': 'cystitis; pyelonephritis; nephrolithiasis'},
#  {'case_number': '193',
#   'app': 'AveyRule3a',
#   'content': 'migraine; cluster headaches; meningitis; hypertension disease; brain tumor'},
#  {'case_number': '182',
#   'app': 'AveyRule3a',
#   'content': 'chronic obstructive pulmonary disease; heart failure; lung cancer; asthma; pericardial effusion; valvular heart disease'},
#  {'case_number': '172',
#   'app': 'AveyRule3a',
#   'content': 'variant angina; myocardial infarction; unstable angina'},
#  {'case_number': '145',
#   'app': 'AveyRule3a',
#   'content': 'acute pancreatitis; peptic ulcer disease; cholelithiasis; acute cholangitis; small bowel obstruction; acute cholecystitis'},
#  {'case_number': '155',
#   'app': 'AveyRule3a',
#   'content': 'otitis media; meningitis; otitis media with effusion; otitis media with tympanic membrane perforated'},
#  {'case_number': '173',
#   'app': 'AveyRule3a',
#   'content': 'polycythemia vera; tension headache; hypertension disease; migraine'},
#  {'case_number': '168',
#   'app': 'AveyRule3a',
#   'content': 'diaper dermatitis; urticaria; contact dermatitis'},
#  {'case_number': '166',
#   'app': 'AveyRule3a',
#   'content': 'primary dysmenorrhea; secondary dysmenorrhea; endometriosis; adenomyosis'},
#  {'case_number': '73',
#   'app': 'AveyRule3a',
#   'content': 'bacterial vaginosis; trichomoniasis; vulvovaginal candidiasis; chlamydia; pelvic inflammatory disease'},
#  {'case_number': '115',
#   'app': 'AveyRule3a',
#   'content': 'pneumothorax; aortic dissection; pulmonary edema; myocardial infarction; unstable angina; pulmonary embolism'},
#  {'case_number': '161',
#   'app': 'AveyRule3a',
#   'content': 'urethritis; chlamydia; trichomoniasis; benign prostatic hyperplasia'},
#  {'case_number': '48',
#   'app': 'AveyRule3a',
#   'content': 'anal fissure; hemorrhoids'},
#  {'case_number': '82',
#   'app': 'AveyRule3a',
#   'content': 'allergic conjunctivitis; viral conjunctivitis; chalazion; blepharitis; nasolacrimal duct obstruction'},
#  {'case_number': '49',
#   'app': 'AveyRule3a',
#   'content': 'lactose intolerance; celiac disease; inflammatory bowel disease; chronic pancreatitis; acute viral gastroenteritis; acute bacterial gastroenteritis'},
#  {'case_number': '169',
#   'app': 'AveyRule3a',
#   'content': 'lactose intolerance; inflammatory bowel disease; abdominal aortic aneurysm; irritable bowel syndrome; colonic polyps; small bowel obstruction'},
#  {'case_number': '157',
#   'app': 'AveyRule3a',
#   'content': 'trichomoniasis; bacterial vaginosis; vulvovaginal candidiasis; pelvic inflammatory disease'},
#  {'case_number': '18',
#   'app': 'AveyRule3a',
#   'content': 'chronic obstructive pulmonary disease; asthma; pneumonia; pericardial effusion; heart failure; valvular heart disease'},
#  {'case_number': '112',
#   'app': 'AveyRule3a',
#   'content': 'diverticulitis; pyelonephritis; infective endocarditis; acute cholangitis; pelvic inflammatory disease'},
#  {'case_number': '171',
#   'app': 'AveyRule3a',
#   'content': 'chronic obstructive pulmonary disease; asthma; pulmonary edema; pericardial effusion; heart failure; valvular heart disease'},
#  {'case_number': '29',
#   'app': 'AveyRule3a',
#   'content': 'urticaria; contact dermatitis; atopic dermatitis; impetigo; scabies; measles'},
#  {'case_number': '3',
#   'app': 'AveyRule3a',
#   'content': 'myocardial infarction; aortic dissection; unstable angina; pneumothorax; pulmonary edema; valvular heart disease'},
#  {'case_number': '197',
#   'app': 'AveyRule3a',
#   'content': 'fibromyalgia; brucellosis; anemia'},
#  {'case_number': '127',
#   'app': 'AveyRule3a',
#   'content': 'aortic dissection; unstable angina; myocardial infarction; pneumothorax; pulmonary embolism; variant angina'},
#  {'case_number': '190',
#   'app': 'AveyRule3a',
#   'content': 'breast infection; acute interstitial nephritis; hiv infection; rheumatic fever'},
#  {'case_number': '25',
#   'app': 'AveyRule3a',
#   'content': 'obstructive sleep apnea'},
#  {'case_number': '104',
#   'app': 'AveyRule3a',
#   'content': 'pneumothorax; aortic dissection; myocardial infarction; stable angina; unstable angina; pulmonary embolism'},
#  {'case_number': '13',
#   'app': 'AveyRule3a',
#   'content': 'chronic obstructive pulmonary disease; asthma; tuberculosis; valvular heart disease; lung cancer; cardiac tamponade'},
#  {'case_number': '121',
#   'app': 'AveyRule3a',
#   'content': 'urethritis; chlamydia; trichomoniasis; benign prostatic hyperplasia; acute prostatitis'},
#  {'case_number': '63',
#   'app': 'AveyRule3a',
#   'content': 'malaria; dengue fever; influenza; osteomyelitis; coronavirus disease 2019; acute bacterial gastroenteritis'},
#  {'case_number': '45',
#   'app': 'AveyRule3a',
#   'content': 'diabetic ketoacidosis; acute appendicitis; peptic ulcer disease; acute pancreatitis; peritonitis; acute bacterial gastroenteritis'}]

# %%
with open("experiments.json","w") as file:
    json.dump(joined, file, indent=4)
